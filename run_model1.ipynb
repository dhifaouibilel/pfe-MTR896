# %%
import os
import os.path as osp
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import  precision_score, recall_score, roc_auc_score, brier_score_loss
from sklearn.base import clone
from sklearn.model_selection import TimeSeriesSplit

from imblearn.under_sampling import RandomUnderSampler

from utils import helpers as hpr
from utils import constants
from utils import classifier_util as clas_util

import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.spatial.distance import squareform
from scipy.stats import mannwhitneyu

# %% [markdown]
# ### Constants

# %%
METRICS = constants.get_metrics()[:-3]

# %% [markdown]
# ### Dependent changes

# %%
df_dependencies = pd.read_csv(osp.join('.', 'Files', 'source_target_evolution_clean.csv'))
# df_dependencies = df_dependencies[(df_dependencies['Source_status']!="NEW")&(df_dependencies['Target_status']!="NEW")]
dependent_changes = set(hpr.flatten_list(df_dependencies[['Source', 'Target']].values))

# %% [markdown]
# ### Load changes

# %%
df_changes = hpr.combine_openstack_data(changes_path="/Changes3/")
# df_changes = df_changes[df_changes["status"]!="NEW"]
# df_changes['is_dependent'] = df_changes['number'].map(lambda nbr: 1 if nbr in dependent_changes else 0)
# Out:
# Reading OpenStack changes...
# OpenStack changes loaded successfully...

# %%
df_changes["number"].nunique()
# Out:
# 712079

# %%
df2 = pd.read_csv("./Files/Data/Test/0.csv")
df2 = pd.merge(
    left=df2, 
    right=df_changes[["number", "status"]], 
    left_on='Source', 
    right_on='number', 
    how='inner',
    suffixes=('_target', '_source')
)
df2 = pd.merge(
    left=df2, 
    right=df_changes[["number", "status"]], 
    left_on='Target', 
    right_on='number', 
    how='inner',
    suffixes=('_source', '_target')
)

# %%
df2[df2["status_target"]=="ABANDONED"]
# Out:
#         Source  Target  related  pctg_inter_dep_cha  src_trgt_co_changed_nbr  \
# 365     273587  275389        0               57.14                        2
# 366     268249  275389        0                3.06                        0
# 367     265978  275389        0               60.00                        6
# 368     266536  275389        0               33.33                        5
# 369     269970  275389        0               32.56                       10
# ...        ...     ...      ...                 ...                      ...
# 131051  322784  333037        0               50.00                        5
# 131052  320999  333037        0               20.00                        3
# 131053  319464  333037        0                1.41                        0
# 131054  317251  333037        0               66.67                        5
# 131055  317559  333037        0               14.29                        0
#
#         dev_in_src_change_nbr  rev_in_src_change_nbr  num_shrd_desc_tkns  \
# 365                         4                      9            0.027027
# 366                         6                      7            0.020833
# 367                         3                     10            0.019608
# 368                         1                     26            0.000000
# 369                        14                     47            0.000000
# ...                       ...                    ...                 ...
# 131051                     10                     20            0.032258
# 131052                      3                      5            0.000000
# 131053                      1                      4            0.000000
# 131054                      4                     10            0.000000
# 131055                      1                      5            0.000000
#
#         num_shrd_file_tkns  desc_sim  ...  code_churn_source  \
# 365               0.054054  0.147101  ...                 16
# 366               0.000000  0.013383  ...                 16
# 367               0.071429  0.110363  ...                 16
# 368               0.000000  0.110214  ...                 16
# 369               0.000000  0.179878  ...                 16
# ...                    ...       ...  ...                ...
# 131051            0.000000  0.480435  ...                173
# 131052            0.000000  0.385169  ...                173
# 131053            0.000000  0.136939  ...                173
# 131054            0.000000  0.605956  ...                173
# 131055            0.000000  0.089063  ...                173
#
#         last_mth_dep_proj_nbr_source  ratio_dep_chan_owner_source  \
# 365                                4                     8.333333
# 366                                4                     8.333333
# 367                                4                     8.333333
# 368                                4                     8.333333
# 369                                4                     8.333333
# ...                              ...                          ...
# 131051                             4                    50.000000
# 131052                             4                    50.000000
# 131053                             4                    50.000000
# 131054                             4                    50.000000
# 131055                             4                    50.000000
#
#         projects_contributed_owner_source  pctg_cross_project_changes_source  \
# 365                                    52                           0.489933
# 366                                    52                           0.489933
# 367                                    52                           0.489933
# 368                                    52                           0.489933
# 369                                    52                           0.489933
# ...                                   ...                                ...
# 131051                                  9                           0.361111
# 131052                                  9                           0.361111
# 131053                                  9                           0.361111
# 131054                                  9                           0.361111
# 131055                                  9                           0.361111
#
#         pctg_cross_project_changes_owner_source  number_source  status_source  \
# 365                                         0.5         273587         MERGED
# 366                                         0.5         268249         MERGED
# 367                                         0.5         265978         MERGED
# 368                                         0.5         266536         MERGED
# 369                                         0.5         269970         MERGED
# ...                                         ...            ...            ...
# 131051                                      0.0         322784         MERGED
# 131052                                      0.0         320999         MERGED
# 131053                                      0.0         319464         MERGED
# 131054                                      0.0         317251         MERGED
# 131055                                      0.0         317559         MERGED
#
#         number_target  status_target
# 365            275389      ABANDONED
# 366            275389      ABANDONED
# 367            275389      ABANDONED
# 368            275389      ABANDONED
# 369            275389      ABANDONED
# ...               ...            ...
# 131051         333037      ABANDONED
# 131052         333037      ABANDONED
# 131053         333037      ABANDONED
# 131054         333037      ABANDONED
# 131055         333037      ABANDONED
#
# [16728 rows x 79 columns]

# %%
df_developer_exp = pd.read_csv(osp.join(".", "Files", "Metrics", "project_changes_owner.csv"))
df_developer_exp['is_dependent'] = df_developer_exp['number'].map(lambda nbr: 1 if nbr in dependent_changes else 0)

# %%
df_changes.loc[(df_changes["insertions"]==100)&(df_changes["is_dependent"]==0), ["number", "added_lines", "insertions"]].sort_values("insertions")
# Out:
#         number                                        added_lines  insertions
# 116      21225  import json from tempest.common.rest_client im...         100
# 378616  489219                                                NaN         100
# 382320  493712   """A decorator for verifying policy enforceme...         100
# 382771  494247  # Licensed under the Apache License, Version 2...         100
# 384375  496203  # # Licensed under the Apache License, Version...         100
# ...        ...                                                ...         ...
# 176807  242556   @mock.patch('ceilometer.pipeline.LOG') def te...         100
# 176853  242615   new_domain = unit.new_domain_ref() domain = u...         100
# 177316  243221   with _utils.shade_exceptions("Error authentic...         100
# 173985  238965  import json def get_property_value(self, obj, ...         100
# 721284  917116  # verify_contents(catalogue, '/etc/nova/provid...         100
#
# [620 rows x 3 columns]

# %%
# combined_output = hpr.combine_file_metrics()
path = osp.join(".", "Files", "file-metrics")

files = hpr.list_file(path)
combined_output = pd.DataFrame()

for file in files:
    df_item = pd.read_csv(osp.join(path, file))
    combined_output = pd.concat((combined_output, df_item))
combined_output.drop(columns=["owner_account_id", 'status'], inplace=True)
# combined_output["changed_files"] = combined_output["changed_files"].map(ast.literal_eval)

# %% [markdown]
# ### Combine features

# %%
metric_path = osp.join('.', 'Files', 'Metrics')
metric_list = [f for f in hpr.list_file(metric_path) if f[:-4]]

# %%
def calc_mod_file_dep_cha(row):
    changed_files = row["changed_files"]
    if type(changed_files) is not list:
        changed_files = []
    return round(100*row['num_mod_file_dep_cha']/len(changed_files), 2) if len(changed_files) != 0 else 0

# %%
df = clas_util.combine_features()
df = pd.merge(
    left=df,
    right=combined_output,
    left_on='number',
    right_on='number',
    how='left',
    suffixes=('_source', '_target')
)
df['pctg_mod_file_dep_cha'] = df.apply(calc_mod_file_dep_cha, axis=1)
# df['is_dependent'] = df['number'].map(lambda nbr: 1 if nbr in dependent_changes else 0)
df = df.drop(columns=[
    "changed_files", "num_mod_file_dep_cha", 'num_build_failures', 'pctg_mod_file_dep_cha'
    ])
# df.fillna(0, inplace=True)

# %%
change_ids = df["number"].unique()

# %%
# Out:
# ./Changes3/data_425.csv succeeded
# ./Changes3/data_343.csv succeeded
# ./Changes3/data_357.csv succeeded
# ./Changes3/data_431.csv succeeded
# ./Changes3/data_419.csv succeeded
# ./Changes3/data_1198.csv succeeded
# ./Changes3/data_1167.csv succeeded
# ./Changes3/data_380.csv succeeded
# ./Changes3/data_1173.csv succeeded
# ./Changes3/data_394.csv succeeded
# ./Changes3/data_141.csv succeeded
# ./Changes3/data_627.csv succeeded
# ./Changes3/data_633.csv succeeded
# ./Changes3/data_2.csv succeeded
# ./Changes3/data_155.csv succeeded
# ./Changes3/data_169.csv succeeded
# ./Changes3/data_26.csv succeeded
# ./Changes3/data_182.csv succeeded
# ./Changes3/data_1365.csv succeeded
# ./Changes3/data_1403.csv succeeded
# ./Changes3/data_1417.csv succeeded
# ./Changes3/data_828.csv succeeded
# ./Changes3/data_196.csv succeeded
# ./Changes3/data_1371.csv succeeded
# ./Changes3/data_32.csv succeeded
# ./Changes3/data_1359.csv succeeded
# ./Changes3/data_800.csv succeeded
# ./Changes3/data_814.csv succeeded
# ./Changes3/data_753.csv succeeded
# ./Changes3/data_747.csv succeeded
# ./Changes3/data_1211.csv succeeded
# ./Changes3/data_948.csv succeeded
# ./Changes3/data_790.csv succeeded
# ./Changes3/data_784.csv succeeded
# ./Changes3/data_1205.csv succeeded
# ./Changes3/data_974.csv succeeded
# ./Changes3/data_960.csv succeeded
# ./Changes3/data_1239.csv succeeded
# ./Changes3/data_551.csv succeeded
# ./Changes3/data_237.csv succeeded
# ./Changes3/data_223.csv succeeded
# ./Changes3/data_545.csv succeeded
# ./Changes3/data_579.csv succeeded
# ./Changes3/data_592.csv succeeded
# ./Changes3/data_1013.csv succeeded
# ./Changes3/data_1007.csv succeeded
# ./Changes3/data_586.csv succeeded
# ./Changes3/data_1006.csv succeeded
# ./Changes3/data_587.csv succeeded
# ./Changes3/data_593.csv succeeded
# ./Changes3/data_1012.csv succeeded
# ./Changes3/data_578.csv succeeded
# ./Changes3/data_222.csv succeeded
# ./Changes3/data_544.csv succeeded
# ./Changes3/data_550.csv succeeded
# ./Changes3/data_236.csv succeeded
# ./Changes3/data_961.csv succeeded
# ./Changes3/data_1238.csv succeeded
# ./Changes3/data_975.csv succeeded
# ./Changes3/data_785.csv succeeded
# ./Changes3/data_1204.csv succeeded
# ./Changes3/data_1210.csv succeeded
# ./Changes3/data_791.csv succeeded
# ./Changes3/data_949.csv succeeded
# ./Changes3/data_746.csv succeeded
# ./Changes3/data_752.csv succeeded
# ./Changes3/data_815.csv succeeded
# ./Changes3/data_1358.csv succeeded
# ./Changes3/data_801.csv succeeded
# ./Changes3/data_829.csv succeeded
# ./Changes3/data_1416.csv succeeded
# ./Changes3/data_33.csv succeeded
# ./Changes3/data_1370.csv succeeded
# ./Changes3/data_197.csv succeeded
# ./Changes3/data_1364.csv succeeded
# ./Changes3/data_183.csv succeeded
# ./Changes3/data_27.csv succeeded
# ./Changes3/data_1402.csv succeeded
# ./Changes3/data_168.csv succeeded
# ./Changes3/data_3.csv succeeded
# ./Changes3/data_632.csv succeeded
# ./Changes3/data_154.csv succeeded
# ./Changes3/data_140.csv succeeded
# ./Changes3/data_626.csv succeeded
# ./Changes3/data_395.csv succeeded
# ./Changes3/data_1172.csv succeeded
# ./Changes3/data_381.csv succeeded
# ./Changes3/data_1166.csv succeeded
# ./Changes3/data_418.csv succeeded
# ./Changes3/data_1199.csv succeeded
# ./Changes3/data_356.csv succeeded
# ./Changes3/data_430.csv succeeded
# ./Changes3/data_424.csv succeeded
# ./Changes3/data_342.csv succeeded
# ./Changes3/data_432.csv succeeded
# ./Changes3/data_354.csv succeeded
# ./Changes3/data_340.csv succeeded
# ./Changes3/data_426.csv succeeded
# ./Changes3/data_368.csv succeeded
# ./Changes3/data_1170.csv succeeded
# ./Changes3/data_397.csv succeeded
# ./Changes3/data_1164.csv succeeded
# ./Changes3/data_383.csv succeeded
# ./Changes3/data_1158.csv succeeded
# ./Changes3/data_156.csv succeeded
# ./Changes3/data_630.csv succeeded
# ./Changes3/data_1.csv succeeded
# ./Changes3/data_624.csv succeeded
# ./Changes3/data_142.csv succeeded
# ./Changes3/data_618.csv succeeded
# ./Changes3/data_1399.csv succeeded
# ./Changes3/data_195.csv succeeded
# ./Changes3/data_1372.csv succeeded
# ./Changes3/data_31.csv succeeded
# ./Changes3/data_1414.csv succeeded
# ./Changes3/data_1400.csv succeeded
# ./Changes3/data_25.csv succeeded
# ./Changes3/data_181.csv succeeded
# ./Changes3/data_1366.csv succeeded
# ./Changes3/data_1428.csv succeeded
# ./Changes3/data_817.csv succeeded
# ./Changes3/data_803.csv succeeded
# ./Changes3/data_19.csv succeeded
# ./Changes3/data_744.csv succeeded
# ./Changes3/data_750.csv succeeded
# ./Changes3/data_988.csv succeeded
# ./Changes3/data_778.csv succeeded
# ./Changes3/data_1206.csv succeeded
# ./Changes3/data_787.csv succeeded
# ./Changes3/data_793.csv succeeded
# ./Changes3/data_1212.csv succeeded
# ./Changes3/data_963.csv succeeded
# ./Changes3/data_977.csv succeeded
# ./Changes3/data_546.csv succeeded
# ./Changes3/data_220.csv succeeded
# ./Changes3/data_234.csv succeeded
# ./Changes3/data_552.csv succeeded
# ./Changes3/data_208.csv succeeded
# ./Changes3/data_585.csv succeeded
# ./Changes3/data_1004.csv succeeded
# ./Changes3/data_1010.csv succeeded
# ./Changes3/data_591.csv succeeded
# ./Changes3/data_1038.csv succeeded
# ./Changes3/data_1039.csv succeeded
# ./Changes3/data_1011.csv succeeded
# ./Changes3/data_590.csv succeeded
# ./Changes3/data_584.csv succeeded
# ./Changes3/data_1005.csv succeeded
# ./Changes3/data_209.csv succeeded
# ./Changes3/data_235.csv succeeded
# ./Changes3/data_553.csv succeeded
# ./Changes3/data_547.csv succeeded
# ./Changes3/data_221.csv succeeded
# ./Changes3/data_976.csv succeeded
# ./Changes3/data_962.csv succeeded
# ./Changes3/data_792.csv succeeded
# ./Changes3/data_1213.csv succeeded
# ./Changes3/data_1207.csv succeeded
# ./Changes3/data_786.csv succeeded
# ./Changes3/data_779.csv succeeded
# ./Changes3/data_989.csv succeeded
# ./Changes3/data_751.csv succeeded
# ./Changes3/data_745.csv succeeded
# ./Changes3/data_802.csv succeeded
# ./Changes3/data_18.csv succeeded
# ./Changes3/data_816.csv succeeded
# ./Changes3/data_1429.csv succeeded
# ./Changes3/data_1401.csv succeeded
# ./Changes3/data_1367.csv succeeded
# ./Changes3/data_180.csv succeeded
# ./Changes3/data_24.csv succeeded
# ./Changes3/data_30.csv succeeded
# ./Changes3/data_1373.csv succeeded
# ./Changes3/data_194.csv succeeded
# ./Changes3/data_1415.csv succeeded
# ./Changes3/data_619.csv succeeded
# ./Changes3/data_1398.csv succeeded
# ./Changes3/data_625.csv succeeded
# ./Changes3/data_143.csv succeeded
# ./Changes3/data_157.csv succeeded
# ./Changes3/data_0.csv succeeded
# ./Changes3/data_631.csv succeeded
# ./Changes3/data_1159.csv succeeded
# ./Changes3/data_382.csv succeeded
# ./Changes3/data_1165.csv succeeded
# ./Changes3/data_396.csv succeeded
# ./Changes3/data_1171.csv succeeded
# ./Changes3/data_369.csv succeeded
# ./Changes3/data_341.csv succeeded
# ./Changes3/data_427.csv succeeded
# ./Changes3/data_433.csv succeeded
# ./Changes3/data_355.csv succeeded
# ./Changes3/data_379.csv succeeded
# ./Changes3/data_351.csv succeeded
# ./Changes3/data_437.csv succeeded
# ./Changes3/data_423.csv succeeded
# ./Changes3/data_345.csv succeeded
# ./Changes3/data_1149.csv succeeded
# ./Changes3/data_392.csv succeeded
# ./Changes3/data_1175.csv succeeded
# ./Changes3/data_386.csv succeeded
# ./Changes3/data_1161.csv succeeded
# ./Changes3/data_609.csv succeeded
# ./Changes3/data_1388.csv succeeded
# ./Changes3/data_635.csv succeeded
# ./Changes3/data_4.csv succeeded
# ./Changes3/data_153.csv succeeded
# ./Changes3/data_147.csv succeeded
# ./Changes3/data_621.csv succeeded
# ./Changes3/data_812.csv succeeded
# ./Changes3/data_1439.csv succeeded
# ./Changes3/data_806.csv succeeded
# ./Changes3/data_1411.csv succeeded
# ./Changes3/data_1377.csv succeeded
# ./Changes3/data_190.csv succeeded
# ./Changes3/data_34.csv succeeded
# ./Changes3/data_20.csv succeeded
# ./Changes3/data_1363.csv succeeded
# ./Changes3/data_184.csv succeeded
# ./Changes3/data_1405.csv succeeded
# ./Changes3/data_769.csv succeeded
# ./Changes3/data_741.csv succeeded
# ./Changes3/data_999.csv succeeded
# ./Changes3/data_755.csv succeeded
# ./Changes3/data_966.csv succeeded
# ./Changes3/data_972.csv succeeded
# ./Changes3/data_782.csv succeeded
# ./Changes3/data_1203.csv succeeded
# ./Changes3/data_1217.csv succeeded
# ./Changes3/data_796.csv succeeded
# ./Changes3/data_219.csv succeeded
# ./Changes3/data_225.csv succeeded
# ./Changes3/data_543.csv succeeded
# ./Changes3/data_557.csv succeeded
# ./Changes3/data_231.csv succeeded
# ./Changes3/data_1029.csv succeeded
# ./Changes3/data_1001.csv succeeded
# ./Changes3/data_580.csv succeeded
# ./Changes3/data_594.csv succeeded
# ./Changes3/data_1015.csv succeeded
# ./Changes3/data_595.csv succeeded
# ./Changes3/data_1014.csv succeeded
# ./Changes3/data_1000.csv succeeded
# ./Changes3/data_581.csv succeeded
# ./Changes3/data_1028.csv succeeded
# ./Changes3/data_556.csv succeeded
# ./Changes3/data_230.csv succeeded
# ./Changes3/data_224.csv succeeded
# ./Changes3/data_542.csv succeeded
# ./Changes3/data_218.csv succeeded
# ./Changes3/data_1216.csv succeeded
# ./Changes3/data_797.csv succeeded
# ./Changes3/data_783.csv succeeded
# ./Changes3/data_1202.csv succeeded
# ./Changes3/data_973.csv succeeded
# ./Changes3/data_967.csv succeeded
# ./Changes3/data_754.csv succeeded
# ./Changes3/data_998.csv succeeded
# ./Changes3/data_740.csv succeeded
# ./Changes3/data_768.csv succeeded
# ./Changes3/data_185.csv succeeded
# ./Changes3/data_1362.csv succeeded
# ./Changes3/data_21.csv succeeded
# ./Changes3/data_1404.csv succeeded
# ./Changes3/data_1410.csv succeeded
# ./Changes3/data_35.csv succeeded
# ./Changes3/data_191.csv succeeded
# ./Changes3/data_1376.csv succeeded
# ./Changes3/data_807.csv succeeded
# ./Changes3/data_1438.csv succeeded
# ./Changes3/data_813.csv succeeded
# ./Changes3/data_146.csv succeeded
# ./Changes3/data_620.csv succeeded
# ./Changes3/data_5.csv succeeded
# ./Changes3/data_634.csv succeeded
# ./Changes3/data_152.csv succeeded
# ./Changes3/data_608.csv succeeded
# ./Changes3/data_1389.csv succeeded
# ./Changes3/data_1160.csv succeeded
# ./Changes3/data_387.csv succeeded
# ./Changes3/data_1174.csv succeeded
# ./Changes3/data_393.csv succeeded
# ./Changes3/data_1148.csv succeeded
# ./Changes3/data_422.csv succeeded
# ./Changes3/data_344.csv succeeded
# ./Changes3/data_350.csv succeeded
# ./Changes3/data_436.csv succeeded
# ./Changes3/data_378.csv succeeded
# ./Changes3/data_408.csv succeeded
# ./Changes3/data_1189.csv succeeded
# ./Changes3/data_346.csv succeeded
# ./Changes3/data_420.csv succeeded
# ./Changes3/data_434.csv succeeded
# ./Changes3/data_352.csv succeeded
# ./Changes3/data_385.csv succeeded
# ./Changes3/data_1162.csv succeeded
# ./Changes3/data_391.csv succeeded
# ./Changes3/data_1176.csv succeeded
# ./Changes3/data_178.csv succeeded
# ./Changes3/data_622.csv succeeded
# ./Changes3/data_144.csv succeeded
# ./Changes3/data_150.csv succeeded
# ./Changes3/data_636.csv succeeded
# ./Changes3/data_7.csv succeeded
# ./Changes3/data_805.csv succeeded
# ./Changes3/data_1348.csv succeeded
# ./Changes3/data_811.csv succeeded
# ./Changes3/data_1406.csv succeeded
# ./Changes3/data_839.csv succeeded
# ./Changes3/data_23.csv succeeded
# ./Changes3/data_1360.csv succeeded
# ./Changes3/data_187.csv succeeded
# ./Changes3/data_1374.csv succeeded
# ./Changes3/data_193.csv succeeded
# ./Changes3/data_37.csv succeeded
# ./Changes3/data_1412.csv succeeded
# ./Changes3/data_756.csv succeeded
# ./Changes3/data_742.csv succeeded
# ./Changes3/data_971.csv succeeded
# ./Changes3/data_1228.csv succeeded
# ./Changes3/data_965.csv succeeded
# ./Changes3/data_795.csv succeeded
# ./Changes3/data_1214.csv succeeded
# ./Changes3/data_1200.csv succeeded
# ./Changes3/data_959.csv succeeded
# ./Changes3/data_781.csv succeeded
# ./Changes3/data_568.csv succeeded
# ./Changes3/data_232.csv succeeded
# ./Changes3/data_554.csv succeeded
# ./Changes3/data_540.csv succeeded
# ./Changes3/data_226.csv succeeded
# ./Changes3/data_1016.csv succeeded
# ./Changes3/data_597.csv succeeded
# ./Changes3/data_583.csv succeeded
# ./Changes3/data_1002.csv succeeded
# ./Changes3/data_582.csv succeeded
# ./Changes3/data_1003.csv succeeded
# ./Changes3/data_1017.csv succeeded
# ./Changes3/data_596.csv succeeded
# ./Changes3/data_541.csv succeeded
# ./Changes3/data_227.csv succeeded
# ./Changes3/data_233.csv succeeded
# ./Changes3/data_555.csv succeeded
# ./Changes3/data_569.csv succeeded
# ./Changes3/data_1201.csv succeeded
# ./Changes3/data_780.csv succeeded
# ./Changes3/data_958.csv succeeded
# ./Changes3/data_794.csv succeeded
# ./Changes3/data_1215.csv succeeded
# ./Changes3/data_964.csv succeeded
# ./Changes3/data_970.csv succeeded
# ./Changes3/data_1229.csv succeeded
# ./Changes3/data_743.csv succeeded
# ./Changes3/data_757.csv succeeded
# ./Changes3/data_36.csv succeeded
# ./Changes3/data_192.csv succeeded
# ./Changes3/data_1375.csv succeeded
# ./Changes3/data_1413.csv succeeded
# ./Changes3/data_838.csv succeeded
# ./Changes3/data_1407.csv succeeded
# ./Changes3/data_186.csv succeeded
# ./Changes3/data_1361.csv succeeded
# ./Changes3/data_22.csv succeeded
# ./Changes3/data_1349.csv succeeded
# ./Changes3/data_810.csv succeeded
# ./Changes3/data_804.csv succeeded
# ./Changes3/data_151.csv succeeded
# ./Changes3/data_6.csv succeeded
# ./Changes3/data_637.csv succeeded
# ./Changes3/data_623.csv succeeded
# ./Changes3/data_145.csv succeeded
# ./Changes3/data_179.csv succeeded
# ./Changes3/data_1177.csv succeeded
# ./Changes3/data_390.csv succeeded
# ./Changes3/data_1163.csv succeeded
# ./Changes3/data_384.csv succeeded
# ./Changes3/data_435.csv succeeded
# ./Changes3/data_353.csv succeeded
# ./Changes3/data_347.csv succeeded
# ./Changes3/data_421.csv succeeded
# ./Changes3/data_409.csv succeeded
# ./Changes3/data_1188.csv succeeded
# ./Changes3/data_320.csv succeeded
# ./Changes3/data_446.csv succeeded
# ./Changes3/data_452.csv succeeded
# ./Changes3/data_334.csv succeeded
# ./Changes3/data_308.csv succeeded
# ./Changes3/data_1104.csv succeeded
# ./Changes3/data_485.csv succeeded
# ./Changes3/data_491.csv succeeded
# ./Changes3/data_1110.csv succeeded
# ./Changes3/data_1138.csv succeeded
# ./Changes3/data_644.csv succeeded
# ./Changes3/data_86.csv succeeded
# ./Changes3/data_122.csv succeeded
# ./Changes3/data_136.csv succeeded
# ./Changes3/data_92.csv succeeded
# ./Changes3/data_888.csv succeeded
# ./Changes3/data_650.csv succeeded
# ./Changes3/data_678.csv succeeded
# ./Changes3/data_1460.csv succeeded
# ./Changes3/data_687.csv succeeded
# ./Changes3/data_1306.csv succeeded
# ./Changes3/data_45.csv succeeded
# ./Changes3/data_51.csv succeeded
# ./Changes3/data_1312.csv succeeded
# ./Changes3/data_1474.csv succeeded
# ./Changes3/data_693.csv succeeded
# ./Changes3/data_863.csv succeeded
# ./Changes3/data_79.csv succeeded
# ./Changes3/data_1448.csv succeeded
# ./Changes3/data_877.csv succeeded
# ./Changes3/data_730.csv succeeded
# ./Changes3/data_724.csv succeeded
# ./Changes3/data_1299.csv succeeded
# ./Changes3/data_718.csv succeeded
# ./Changes3/data_1272.csv succeeded
# ./Changes3/data_1266.csv succeeded
# ./Changes3/data_917.csv succeeded
# ./Changes3/data_903.csv succeeded
# ./Changes3/data_254.csv succeeded
# ./Changes3/data_532.csv succeeded
# ./Changes3/data_526.csv succeeded
# ./Changes3/data_240.csv succeeded
# ./Changes3/data_268.csv succeeded
# ./Changes3/data_297.csv succeeded
# ./Changes3/data_1070.csv succeeded
# ./Changes3/data_283.csv succeeded
# ./Changes3/data_1064.csv succeeded
# ./Changes3/data_1058.csv succeeded
# ./Changes3/data_1059.csv succeeded
# ./Changes3/data_1065.csv succeeded
# ./Changes3/data_282.csv succeeded
# ./Changes3/data_1071.csv succeeded
# ./Changes3/data_296.csv succeeded
# ./Changes3/data_269.csv succeeded
# ./Changes3/data_527.csv succeeded
# ./Changes3/data_241.csv succeeded
# ./Changes3/data_255.csv succeeded
# ./Changes3/data_533.csv succeeded
# ./Changes3/data_902.csv succeeded
# ./Changes3/data_916.csv succeeded
# ./Changes3/data_1267.csv succeeded
# ./Changes3/data_1273.csv succeeded
# ./Changes3/data_1298.csv succeeded
# ./Changes3/data_719.csv succeeded
# ./Changes3/data_725.csv succeeded
# ./Changes3/data_731.csv succeeded
# ./Changes3/data_876.csv succeeded
# ./Changes3/data_1449.csv succeeded
# ./Changes3/data_862.csv succeeded
# ./Changes3/data_78.csv succeeded
# ./Changes3/data_1313.csv succeeded
# ./Changes3/data_50.csv succeeded
# ./Changes3/data_692.csv succeeded
# ./Changes3/data_1475.csv succeeded
# ./Changes3/data_686.csv succeeded
# ./Changes3/data_1461.csv succeeded
# ./Changes3/data_44.csv succeeded
# ./Changes3/data_1307.csv succeeded
# ./Changes3/data_679.csv succeeded
# ./Changes3/data_93.csv succeeded
# ./Changes3/data_137.csv succeeded
# ./Changes3/data_651.csv succeeded
# ./Changes3/data_889.csv succeeded
# ./Changes3/data_645.csv succeeded
# ./Changes3/data_123.csv succeeded
# ./Changes3/data_87.csv succeeded
# ./Changes3/data_1139.csv succeeded
# ./Changes3/data_490.csv succeeded
# ./Changes3/data_1111.csv succeeded
# ./Changes3/data_1105.csv succeeded
# ./Changes3/data_484.csv succeeded
# ./Changes3/data_309.csv succeeded
# ./Changes3/data_453.csv succeeded
# ./Changes3/data_335.csv succeeded
# ./Changes3/data_321.csv succeeded
# ./Changes3/data_447.csv succeeded
# ./Changes3/data_337.csv succeeded
# ./Changes3/data_451.csv succeeded
# ./Changes3/data_445.csv succeeded
# ./Changes3/data_323.csv succeeded
# ./Changes3/data_479.csv succeeded
# ./Changes3/data_1113.csv succeeded
# ./Changes3/data_492.csv succeeded
# ./Changes3/data_486.csv succeeded
# ./Changes3/data_1107.csv succeeded
# ./Changes3/data_653.csv succeeded
# ./Changes3/data_135.csv succeeded
# ./Changes3/data_91.csv succeeded
# ./Changes3/data_85.csv succeeded
# ./Changes3/data_121.csv succeeded
# ./Changes3/data_647.csv succeeded
# ./Changes3/data_109.csv succeeded
# ./Changes3/data_1477.csv succeeded
# ./Changes3/data_690.csv succeeded
# ./Changes3/data_848.csv succeeded
# ./Changes3/data_52.csv succeeded
# ./Changes3/data_1311.csv succeeded
# ./Changes3/data_1305.csv succeeded
# ./Changes3/data_46.csv succeeded
# ./Changes3/data_1463.csv succeeded
# ./Changes3/data_684.csv succeeded
# ./Changes3/data_874.csv succeeded
# ./Changes3/data_1339.csv succeeded
# ./Changes3/data_860.csv succeeded
# ./Changes3/data_727.csv succeeded
# ./Changes3/data_733.csv succeeded
# ./Changes3/data_1265.csv succeeded
# ./Changes3/data_1271.csv succeeded
# ./Changes3/data_928.csv succeeded
# ./Changes3/data_900.csv succeeded
# ./Changes3/data_1259.csv succeeded
# ./Changes3/data_914.csv succeeded
# ./Changes3/data_243.csv succeeded
# ./Changes3/data_525.csv succeeded
# ./Changes3/data_531.csv succeeded
# ./Changes3/data_257.csv succeeded
# ./Changes3/data_1098.csv succeeded
# ./Changes3/data_519.csv succeeded
# ./Changes3/data_280.csv succeeded
# ./Changes3/data_1067.csv succeeded
# ./Changes3/data_294.csv succeeded
# ./Changes3/data_1073.csv succeeded
# ./Changes3/data_1072.csv succeeded
# ./Changes3/data_295.csv succeeded
# ./Changes3/data_1066.csv succeeded
# ./Changes3/data_281.csv succeeded
# ./Changes3/data_1099.csv succeeded
# ./Changes3/data_518.csv succeeded
# ./Changes3/data_530.csv succeeded
# ./Changes3/data_256.csv succeeded
# ./Changes3/data_242.csv succeeded
# ./Changes3/data_524.csv succeeded
# ./Changes3/data_915.csv succeeded
# ./Changes3/data_901.csv succeeded
# ./Changes3/data_1258.csv succeeded
# ./Changes3/data_1270.csv succeeded
# ./Changes3/data_929.csv succeeded
# ./Changes3/data_1264.csv succeeded
# ./Changes3/data_732.csv succeeded
# ./Changes3/data_726.csv succeeded
# ./Changes3/data_1338.csv succeeded
# ./Changes3/data_861.csv succeeded
# ./Changes3/data_875.csv succeeded
# ./Changes3/data_47.csv succeeded
# ./Changes3/data_1304.csv succeeded
# ./Changes3/data_685.csv succeeded
# ./Changes3/data_1462.csv succeeded
# ./Changes3/data_849.csv succeeded
# ./Changes3/data_691.csv succeeded
# ./Changes3/data_1476.csv succeeded
# ./Changes3/data_1310.csv succeeded
# ./Changes3/data_53.csv succeeded
# ./Changes3/data_108.csv succeeded
# ./Changes3/data_120.csv succeeded
# ./Changes3/data_84.csv succeeded
# ./Changes3/data_646.csv succeeded
# ./Changes3/data_652.csv succeeded
# ./Changes3/data_90.csv succeeded
# ./Changes3/data_134.csv succeeded
# ./Changes3/data_487.csv succeeded
# ./Changes3/data_1106.csv succeeded
# ./Changes3/data_1112.csv succeeded
# ./Changes3/data_493.csv succeeded
# ./Changes3/data_478.csv succeeded
# ./Changes3/data_444.csv succeeded
# ./Changes3/data_322.csv succeeded
# ./Changes3/data_336.csv succeeded
# ./Changes3/data_450.csv succeeded
# ./Changes3/data_468.csv succeeded
# ./Changes3/data_454.csv succeeded
# ./Changes3/data_332.csv succeeded
# ./Changes3/data_326.csv succeeded
# ./Changes3/data_440.csv succeeded
# ./Changes3/data_497.csv succeeded
# ./Changes3/data_1116.csv succeeded
# ./Changes3/data_1102.csv succeeded
# ./Changes3/data_483.csv succeeded
# ./Changes3/data_118.csv succeeded
# ./Changes3/data_130.csv succeeded
# ./Changes3/data_94.csv succeeded
# ./Changes3/data_656.csv succeeded
# ./Changes3/data_642.csv succeeded
# ./Changes3/data_80.csv succeeded
# ./Changes3/data_124.csv succeeded
# ./Changes3/data_1328.csv succeeded
# ./Changes3/data_871.csv succeeded
# ./Changes3/data_865.csv succeeded
# ./Changes3/data_57.csv succeeded
# ./Changes3/data_1314.csv succeeded
# ./Changes3/data_695.csv succeeded
# ./Changes3/data_1472.csv succeeded
# ./Changes3/data_681.csv succeeded
# ./Changes3/data_1466.csv succeeded
# ./Changes3/data_859.csv succeeded
# ./Changes3/data_1300.csv succeeded
# ./Changes3/data_43.csv succeeded
# ./Changes3/data_722.csv succeeded
# ./Changes3/data_736.csv succeeded
# ./Changes3/data_905.csv succeeded
# ./Changes3/data_911.csv succeeded
# ./Changes3/data_1248.csv succeeded
# ./Changes3/data_1260.csv succeeded
# ./Changes3/data_939.csv succeeded
# ./Changes3/data_1274.csv succeeded
# ./Changes3/data_1089.csv succeeded
# ./Changes3/data_508.csv succeeded
# ./Changes3/data_520.csv succeeded
# ./Changes3/data_246.csv succeeded
# ./Changes3/data_252.csv succeeded
# ./Changes3/data_534.csv succeeded
# ./Changes3/data_1062.csv succeeded
# ./Changes3/data_285.csv succeeded
# ./Changes3/data_1076.csv succeeded
# ./Changes3/data_291.csv succeeded
# ./Changes3/data_290.csv succeeded
# ./Changes3/data_1077.csv succeeded
# ./Changes3/data_284.csv succeeded
# ./Changes3/data_1063.csv succeeded
# ./Changes3/data_253.csv succeeded
# ./Changes3/data_535.csv succeeded
# ./Changes3/data_521.csv succeeded
# ./Changes3/data_247.csv succeeded
# ./Changes3/data_1088.csv succeeded
# ./Changes3/data_509.csv succeeded
# ./Changes3/data_1275.csv succeeded
# ./Changes3/data_1261.csv succeeded
# ./Changes3/data_938.csv succeeded
# ./Changes3/data_910.csv succeeded
# ./Changes3/data_1249.csv succeeded
# ./Changes3/data_904.csv succeeded
# ./Changes3/data_737.csv succeeded
# ./Changes3/data_723.csv succeeded
# ./Changes3/data_858.csv succeeded
# ./Changes3/data_1467.csv succeeded
# ./Changes3/data_680.csv succeeded
# ./Changes3/data_42.csv succeeded
# ./Changes3/data_1301.csv succeeded
# ./Changes3/data_1315.csv succeeded
# ./Changes3/data_56.csv succeeded
# ./Changes3/data_1473.csv succeeded
# ./Changes3/data_694.csv succeeded
# ./Changes3/data_864.csv succeeded
# ./Changes3/data_1329.csv succeeded
# ./Changes3/data_870.csv succeeded
# ./Changes3/data_643.csv succeeded
# ./Changes3/data_125.csv succeeded
# ./Changes3/data_81.csv succeeded
# ./Changes3/data_95.csv succeeded
# ./Changes3/data_131.csv succeeded
# ./Changes3/data_657.csv succeeded
# ./Changes3/data_119.csv succeeded
# ./Changes3/data_1103.csv succeeded
# ./Changes3/data_482.csv succeeded
# ./Changes3/data_496.csv succeeded
# ./Changes3/data_1117.csv succeeded
# ./Changes3/data_327.csv succeeded
# ./Changes3/data_441.csv succeeded
# ./Changes3/data_455.csv succeeded
# ./Changes3/data_333.csv succeeded
# ./Changes3/data_469.csv succeeded
# ./Changes3/data_319.csv succeeded
# ./Changes3/data_443.csv succeeded
# ./Changes3/data_325.csv succeeded
# ./Changes3/data_331.csv succeeded
# ./Changes3/data_457.csv succeeded
# ./Changes3/data_1129.csv succeeded
# ./Changes3/data_480.csv succeeded
# ./Changes3/data_1101.csv succeeded
# ./Changes3/data_1115.csv succeeded
# ./Changes3/data_494.csv succeeded
# ./Changes3/data_669.csv succeeded
# ./Changes3/data_83.csv succeeded
# ./Changes3/data_127.csv succeeded
# ./Changes3/data_899.csv succeeded
# ./Changes3/data_641.csv succeeded
# ./Changes3/data_655.csv succeeded
# ./Changes3/data_133.csv succeeded
# ./Changes3/data_97.csv succeeded
# ./Changes3/data_1459.csv succeeded
# ./Changes3/data_866.csv succeeded
# ./Changes3/data_872.csv succeeded
# ./Changes3/data_68.csv succeeded
# ./Changes3/data_1303.csv succeeded
# ./Changes3/data_40.csv succeeded
# ./Changes3/data_682.csv succeeded
# ./Changes3/data_1465.csv succeeded
# ./Changes3/data_696.csv succeeded
# ./Changes3/data_1471.csv succeeded
# ./Changes3/data_54.csv succeeded
# ./Changes3/data_1317.csv succeeded
# ./Changes3/data_1288.csv succeeded
# ./Changes3/data_709.csv succeeded
# ./Changes3/data_735.csv succeeded
# ./Changes3/data_721.csv succeeded
# ./Changes3/data_912.csv succeeded
# ./Changes3/data_906.csv succeeded
# ./Changes3/data_1277.csv succeeded
# ./Changes3/data_1263.csv succeeded
# ./Changes3/data_279.csv succeeded
# ./Changes3/data_537.csv succeeded
# ./Changes3/data_251.csv succeeded
# ./Changes3/data_245.csv succeeded
# ./Changes3/data_523.csv succeeded
# ./Changes3/data_1049.csv succeeded
# ./Changes3/data_1075.csv succeeded
# ./Changes3/data_292.csv succeeded
# ./Changes3/data_1061.csv succeeded
# ./Changes3/data_286.csv succeeded
# ./Changes3/data_287.csv succeeded
# ./Changes3/data_1060.csv succeeded
# ./Changes3/data_293.csv succeeded
# ./Changes3/data_1074.csv succeeded
# ./Changes3/data_1048.csv succeeded
# ./Changes3/data_244.csv succeeded
# ./Changes3/data_522.csv succeeded
# ./Changes3/data_536.csv succeeded
# ./Changes3/data_250.csv succeeded
# ./Changes3/data_278.csv succeeded
# ./Changes3/data_1262.csv succeeded
# ./Changes3/data_1276.csv succeeded
# ./Changes3/data_907.csv succeeded
# ./Changes3/data_913.csv succeeded
# ./Changes3/data_720.csv succeeded
# ./Changes3/data_734.csv succeeded
# ./Changes3/data_1289.csv succeeded
# ./Changes3/data_708.csv succeeded
# ./Changes3/data_1470.csv succeeded
# ./Changes3/data_697.csv succeeded
# ./Changes3/data_1316.csv succeeded
# ./Changes3/data_55.csv succeeded
# ./Changes3/data_41.csv succeeded
# ./Changes3/data_1302.csv succeeded
# ./Changes3/data_1464.csv succeeded
# ./Changes3/data_683.csv succeeded
# ./Changes3/data_873.csv succeeded
# ./Changes3/data_69.csv succeeded
# ./Changes3/data_867.csv succeeded
# ./Changes3/data_1458.csv succeeded
# ./Changes3/data_654.csv succeeded
# ./Changes3/data_96.csv succeeded
# ./Changes3/data_132.csv succeeded
# ./Changes3/data_126.csv succeeded
# ./Changes3/data_82.csv succeeded
# ./Changes3/data_640.csv succeeded
# ./Changes3/data_898.csv succeeded
# ./Changes3/data_668.csv succeeded
# ./Changes3/data_1114.csv succeeded
# ./Changes3/data_495.csv succeeded
# ./Changes3/data_481.csv succeeded
# ./Changes3/data_1100.csv succeeded
# ./Changes3/data_1128.csv succeeded
# ./Changes3/data_330.csv succeeded
# ./Changes3/data_456.csv succeeded
# ./Changes3/data_442.csv succeeded
# ./Changes3/data_324.csv succeeded
# ./Changes3/data_318.csv succeeded
# ./Changes3/data_301.csv succeeded
# ./Changes3/data_467.csv succeeded
# ./Changes3/data_473.csv succeeded
# ./Changes3/data_315.csv succeeded
# ./Changes3/data_329.csv succeeded
# ./Changes3/data_1125.csv succeeded
# ./Changes3/data_1131.csv succeeded
# ./Changes3/data_1119.csv succeeded
# ./Changes3/data_498.csv succeeded
# ./Changes3/data_1482.csv succeeded
# ./Changes3/data_665.csv succeeded
# ./Changes3/data_103.csv succeeded
# ./Changes3/data_117.csv succeeded
# ./Changes3/data_671.csv succeeded
# ./Changes3/data_881.csv succeeded
# ./Changes3/data_659.csv succeeded
# ./Changes3/data_895.csv succeeded
# ./Changes3/data_1441.csv succeeded
# ./Changes3/data_64.csv succeeded
# ./Changes3/data_1327.csv succeeded
# ./Changes3/data_1333.csv succeeded
# ./Changes3/data_70.csv succeeded
# ./Changes3/data_1455.csv succeeded
# ./Changes3/data_842.csv succeeded
# ./Changes3/data_58.csv succeeded
# ./Changes3/data_1469.csv succeeded
# ./Changes3/data_856.csv succeeded
# ./Changes3/data_711.csv succeeded
# ./Changes3/data_1290.csv succeeded
# ./Changes3/data_1284.csv succeeded
# ./Changes3/data_705.csv succeeded
# ./Changes3/data_739.csv succeeded
# ./Changes3/data_1253.csv succeeded
# ./Changes3/data_1247.csv succeeded
# ./Changes3/data_936.csv succeeded
# ./Changes3/data_922.csv succeeded
# ./Changes3/data_275.csv succeeded
# ./Changes3/data_1092.csv succeeded
# ./Changes3/data_513.csv succeeded
# ./Changes3/data_507.csv succeeded
# ./Changes3/data_261.csv succeeded
# ./Changes3/data_1086.csv succeeded
# ./Changes3/data_249.csv succeeded
# ./Changes3/data_1051.csv succeeded
# ./Changes3/data_1045.csv succeeded
# ./Changes3/data_1079.csv succeeded
# ./Changes3/data_1078.csv succeeded
# ./Changes3/data_1044.csv succeeded
# ./Changes3/data_1050.csv succeeded
# ./Changes3/data_248.csv succeeded
# ./Changes3/data_506.csv succeeded
# ./Changes3/data_1087.csv succeeded
# ./Changes3/data_260.csv succeeded
# ./Changes3/data_1093.csv succeeded
# ./Changes3/data_274.csv succeeded
# ./Changes3/data_512.csv succeeded
# ./Changes3/data_923.csv succeeded
# ./Changes3/data_937.csv succeeded
# ./Changes3/data_1246.csv succeeded
# ./Changes3/data_1252.csv succeeded
# ./Changes3/data_738.csv succeeded
# ./Changes3/data_1285.csv succeeded
# ./Changes3/data_704.csv succeeded
# ./Changes3/data_710.csv succeeded
# ./Changes3/data_1291.csv succeeded
# ./Changes3/data_857.csv succeeded
# ./Changes3/data_1468.csv succeeded
# ./Changes3/data_843.csv succeeded
# ./Changes3/data_59.csv succeeded
# ./Changes3/data_71.csv succeeded
# ./Changes3/data_1332.csv succeeded
# ./Changes3/data_1454.csv succeeded
# ./Changes3/data_1440.csv succeeded
# ./Changes3/data_1326.csv succeeded
# ./Changes3/data_65.csv succeeded
# ./Changes3/data_894.csv succeeded
# ./Changes3/data_658.csv succeeded
# ./Changes3/data_880.csv succeeded
# ./Changes3/data_116.csv succeeded
# ./Changes3/data_670.csv succeeded
# ./Changes3/data_664.csv succeeded
# ./Changes3/data_1483.csv succeeded
# ./Changes3/data_102.csv succeeded
# ./Changes3/data_1118.csv succeeded
# ./Changes3/data_499.csv succeeded
# ./Changes3/data_1130.csv succeeded
# ./Changes3/data_1124.csv succeeded
# ./Changes3/data_328.csv succeeded
# ./Changes3/data_472.csv succeeded
# ./Changes3/data_314.csv succeeded
# ./Changes3/data_300.csv succeeded
# ./Changes3/data_466.csv succeeded
# ./Changes3/data_316.csv succeeded
# ./Changes3/data_470.csv succeeded
# ./Changes3/data_464.csv succeeded
# ./Changes3/data_302.csv succeeded
# ./Changes3/data_458.csv succeeded
# ./Changes3/data_1132.csv succeeded
# ./Changes3/data_1126.csv succeeded
# ./Changes3/data_672.csv succeeded
# ./Changes3/data_114.csv succeeded
# ./Changes3/data_100.csv succeeded
# ./Changes3/data_1481.csv succeeded
# ./Changes3/data_666.csv succeeded
# ./Changes3/data_896.csv succeeded
# ./Changes3/data_128.csv succeeded
# ./Changes3/data_98.csv succeeded
# ./Changes3/data_882.csv succeeded
# ./Changes3/data_1456.csv succeeded
# ./Changes3/data_869.csv succeeded
# ./Changes3/data_1330.csv succeeded
# ./Changes3/data_73.csv succeeded
# ./Changes3/data_67.csv succeeded
# ./Changes3/data_1324.csv succeeded
# ./Changes3/data_1442.csv succeeded
# ./Changes3/data_855.csv succeeded
# ./Changes3/data_1318.csv succeeded
# ./Changes3/data_699.csv succeeded
# ./Changes3/data_841.csv succeeded
# ./Changes3/data_706.csv succeeded
# ./Changes3/data_1287.csv succeeded
# ./Changes3/data_1293.csv succeeded
# ./Changes3/data_712.csv succeeded
# ./Changes3/data_1244.csv succeeded
# ./Changes3/data_1250.csv succeeded
# ./Changes3/data_909.csv succeeded
# ./Changes3/data_921.csv succeeded
# ./Changes3/data_1278.csv succeeded
# ./Changes3/data_935.csv succeeded
# ./Changes3/data_262.csv succeeded
# ./Changes3/data_1085.csv succeeded
# ./Changes3/data_504.csv succeeded
# ./Changes3/data_510.csv succeeded
# ./Changes3/data_276.csv succeeded
# ./Changes3/data_1091.csv succeeded
# ./Changes3/data_538.csv succeeded
# ./Changes3/data_1046.csv succeeded
# ./Changes3/data_1052.csv succeeded
# ./Changes3/data_289.csv succeeded
# ./Changes3/data_288.csv succeeded
# ./Changes3/data_1053.csv succeeded
# ./Changes3/data_1047.csv succeeded
# ./Changes3/data_539.csv succeeded
# ./Changes3/data_511.csv succeeded
# ./Changes3/data_1090.csv succeeded
# ./Changes3/data_277.csv succeeded
# ./Changes3/data_1084.csv succeeded
# ./Changes3/data_263.csv succeeded
# ./Changes3/data_505.csv succeeded
# ./Changes3/data_934.csv succeeded
# ./Changes3/data_920.csv succeeded
# ./Changes3/data_1279.csv succeeded
# ./Changes3/data_1251.csv succeeded
# ./Changes3/data_908.csv succeeded
# ./Changes3/data_1245.csv succeeded
# ./Changes3/data_1292.csv succeeded
# ./Changes3/data_713.csv succeeded
# ./Changes3/data_707.csv succeeded
# ./Changes3/data_1286.csv succeeded
# ./Changes3/data_1319.csv succeeded
# ./Changes3/data_840.csv succeeded
# ./Changes3/data_698.csv succeeded
# ./Changes3/data_854.csv succeeded
# ./Changes3/data_1325.csv succeeded
# ./Changes3/data_66.csv succeeded
# ./Changes3/data_1443.csv succeeded
# ./Changes3/data_868.csv succeeded
# ./Changes3/data_1457.csv succeeded
# ./Changes3/data_72.csv succeeded
# ./Changes3/data_1331.csv succeeded
# ./Changes3/data_99.csv succeeded
# ./Changes3/data_883.csv succeeded
# ./Changes3/data_897.csv succeeded
# ./Changes3/data_129.csv succeeded
# ./Changes3/data_101.csv succeeded
# ./Changes3/data_667.csv succeeded
# ./Changes3/data_1480.csv succeeded
# ./Changes3/data_673.csv succeeded
# ./Changes3/data_115.csv succeeded
# ./Changes3/data_1127.csv succeeded
# ./Changes3/data_1133.csv succeeded
# ./Changes3/data_459.csv succeeded
# ./Changes3/data_465.csv succeeded
# ./Changes3/data_303.csv succeeded
# ./Changes3/data_317.csv succeeded
# ./Changes3/data_471.csv succeeded
# ./Changes3/data_449.csv succeeded
# ./Changes3/data_475.csv succeeded
# ./Changes3/data_313.csv succeeded
# ./Changes3/data_307.csv succeeded
# ./Changes3/data_461.csv succeeded
# ./Changes3/data_1137.csv succeeded
# ./Changes3/data_1123.csv succeeded
# ./Changes3/data_89.csv succeeded
# ./Changes3/data_893.csv succeeded
# ./Changes3/data_887.csv succeeded
# ./Changes3/data_139.csv succeeded
# ./Changes3/data_111.csv succeeded
# ./Changes3/data_677.csv succeeded
# ./Changes3/data_663.csv succeeded
# ./Changes3/data_1484.csv succeeded
# ./Changes3/data_105.csv succeeded
# ./Changes3/data_1309.csv succeeded
# ./Changes3/data_688.csv succeeded
# ./Changes3/data_850.csv succeeded
# ./Changes3/data_844.csv succeeded
# ./Changes3/data_1335.csv succeeded
# ./Changes3/data_76.csv succeeded
# ./Changes3/data_1453.csv succeeded
# ./Changes3/data_1447.csv succeeded
# ./Changes3/data_878.csv succeeded
# ./Changes3/data_62.csv succeeded
# ./Changes3/data_1321.csv succeeded
# ./Changes3/data_1282.csv succeeded
# ./Changes3/data_703.csv succeeded
# ./Changes3/data_717.csv succeeded
# ./Changes3/data_1296.csv succeeded
# ./Changes3/data_924.csv succeeded
# ./Changes3/data_930.csv succeeded
# ./Changes3/data_1269.csv succeeded
# ./Changes3/data_1241.csv succeeded
# ./Changes3/data_918.csv succeeded
# ./Changes3/data_1255.csv succeeded
# ./Changes3/data_529.csv succeeded
# ./Changes3/data_501.csv succeeded
# ./Changes3/data_1080.csv succeeded
# ./Changes3/data_267.csv succeeded
# ./Changes3/data_1094.csv succeeded
# ./Changes3/data_273.csv succeeded
# ./Changes3/data_515.csv succeeded
# ./Changes3/data_298.csv succeeded
# ./Changes3/data_1043.csv succeeded
# ./Changes3/data_1057.csv succeeded
# ./Changes3/data_1056.csv succeeded
# ./Changes3/data_1042.csv succeeded
# ./Changes3/data_299.csv succeeded
# ./Changes3/data_272.csv succeeded
# ./Changes3/data_1095.csv succeeded
# ./Changes3/data_514.csv succeeded
# ./Changes3/data_500.csv succeeded
# ./Changes3/data_266.csv succeeded
# ./Changes3/data_1081.csv succeeded
# ./Changes3/data_528.csv succeeded
# ./Changes3/data_1254.csv succeeded
# ./Changes3/data_1240.csv succeeded
# ./Changes3/data_919.csv succeeded
# ./Changes3/data_931.csv succeeded
# ./Changes3/data_1268.csv succeeded
# ./Changes3/data_925.csv succeeded
# ./Changes3/data_716.csv succeeded
# ./Changes3/data_1297.csv succeeded
# ./Changes3/data_1283.csv succeeded
# ./Changes3/data_702.csv succeeded
# ./Changes3/data_879.csv succeeded
# ./Changes3/data_1446.csv succeeded
# ./Changes3/data_1320.csv succeeded
# ./Changes3/data_63.csv succeeded
# ./Changes3/data_77.csv succeeded
# ./Changes3/data_1334.csv succeeded
# ./Changes3/data_1452.csv succeeded
# ./Changes3/data_845.csv succeeded
# ./Changes3/data_1308.csv succeeded
# ./Changes3/data_851.csv succeeded
# ./Changes3/data_689.csv succeeded
# ./Changes3/data_1485.csv succeeded
# ./Changes3/data_662.csv succeeded
# ./Changes3/data_104.csv succeeded
# ./Changes3/data_110.csv succeeded
# ./Changes3/data_676.csv succeeded
# ./Changes3/data_886.csv succeeded
# ./Changes3/data_138.csv succeeded
# ./Changes3/data_88.csv succeeded
# ./Changes3/data_892.csv succeeded
# ./Changes3/data_1122.csv succeeded
# ./Changes3/data_1136.csv succeeded
# ./Changes3/data_306.csv succeeded
# ./Changes3/data_460.csv succeeded
# ./Changes3/data_474.csv succeeded
# ./Changes3/data_312.csv succeeded
# ./Changes3/data_448.csv succeeded
# ./Changes3/data_338.csv succeeded
# ./Changes3/data_462.csv succeeded
# ./Changes3/data_304.csv succeeded
# ./Changes3/data_310.csv succeeded
# ./Changes3/data_476.csv succeeded
# ./Changes3/data_1108.csv succeeded
# ./Changes3/data_489.csv succeeded
# ./Changes3/data_1120.csv succeeded
# ./Changes3/data_1134.csv succeeded
# ./Changes3/data_884.csv succeeded
# ./Changes3/data_890.csv succeeded
# ./Changes3/data_648.csv succeeded
# ./Changes3/data_106.csv succeeded
# ./Changes3/data_660.csv succeeded
# ./Changes3/data_674.csv succeeded
# ./Changes3/data_112.csv succeeded
# ./Changes3/data_1478.csv succeeded
# ./Changes3/data_847.csv succeeded
# ./Changes3/data_853.csv succeeded
# ./Changes3/data_49.csv succeeded
# ./Changes3/data_61.csv succeeded
# ./Changes3/data_1322.csv succeeded
# ./Changes3/data_1444.csv succeeded
# ./Changes3/data_1450.csv succeeded
# ./Changes3/data_1336.csv succeeded
# ./Changes3/data_75.csv succeeded
# ./Changes3/data_728.csv succeeded
# ./Changes3/data_1295.csv succeeded
# ./Changes3/data_714.csv succeeded
# ./Changes3/data_700.csv succeeded
# ./Changes3/data_1281.csv succeeded
# ./Changes3/data_933.csv succeeded
# ./Changes3/data_927.csv succeeded
# ./Changes3/data_1256.csv succeeded
# ./Changes3/data_1242.csv succeeded
# ./Changes3/data_258.csv succeeded
# ./Changes3/data_516.csv succeeded
# ./Changes3/data_1097.csv succeeded
# ./Changes3/data_270.csv succeeded
# ./Changes3/data_1083.csv succeeded
# ./Changes3/data_264.csv succeeded
# ./Changes3/data_502.csv succeeded
# ./Changes3/data_1068.csv succeeded
# ./Changes3/data_1054.csv succeeded
# ./Changes3/data_1040.csv succeeded
# ./Changes3/data_1041.csv succeeded
# ./Changes3/data_1055.csv succeeded
# ./Changes3/data_1069.csv succeeded
# ./Changes3/data_265.csv succeeded
# ./Changes3/data_1082.csv succeeded
# ./Changes3/data_503.csv succeeded
# ./Changes3/data_517.csv succeeded
# ./Changes3/data_271.csv succeeded
# ./Changes3/data_1096.csv succeeded
# ./Changes3/data_259.csv succeeded
# ./Changes3/data_1243.csv succeeded
# ./Changes3/data_1257.csv succeeded
# ./Changes3/data_926.csv succeeded
# ./Changes3/data_932.csv succeeded
# ./Changes3/data_701.csv succeeded
# ./Changes3/data_1280.csv succeeded
# ./Changes3/data_1294.csv succeeded
# ./Changes3/data_715.csv succeeded
# ./Changes3/data_729.csv succeeded
# ./Changes3/data_1451.csv succeeded
# ./Changes3/data_74.csv succeeded
# ./Changes3/data_1337.csv succeeded
# ./Changes3/data_1323.csv succeeded
# ./Changes3/data_60.csv succeeded
# ./Changes3/data_1445.csv succeeded
# ./Changes3/data_852.csv succeeded
# ./Changes3/data_48.csv succeeded
# ./Changes3/data_846.csv succeeded
# ./Changes3/data_1479.csv succeeded
# ./Changes3/data_675.csv succeeded
# ./Changes3/data_113.csv succeeded
# ./Changes3/data_107.csv succeeded
# ./Changes3/data_661.csv succeeded
# ./Changes3/data_649.csv succeeded
# ./Changes3/data_891.csv succeeded
# ./Changes3/data_885.csv succeeded
# ./Changes3/data_1135.csv succeeded
# ./Changes3/data_1121.csv succeeded
# ./Changes3/data_1109.csv succeeded
# ./Changes3/data_488.csv succeeded
# ./Changes3/data_311.csv succeeded
# ./Changes3/data_477.csv succeeded
# ./Changes3/data_463.csv succeeded
# ./Changes3/data_305.csv succeeded
# ./Changes3/data_339.csv succeeded
# ./Changes3/data_404.csv succeeded
# ./Changes3/data_1185.csv succeeded
# ./Changes3/data_362.csv succeeded
# ./Changes3/data_1191.csv succeeded
# ./Changes3/data_376.csv succeeded
# ./Changes3/data_410.csv succeeded
# ./Changes3/data_438.csv succeeded
# ./Changes3/data_1146.csv succeeded
# ./Changes3/data_1152.csv succeeded
# ./Changes3/data_389.csv succeeded
# ./Changes3/data_160.csv succeeded
# ./Changes3/data_1387.csv succeeded
# ./Changes3/data_606.csv succeeded
# ./Changes3/data_612.csv succeeded
# ./Changes3/data_174.csv succeeded
# ./Changes3/data_1393.csv succeeded
# ./Changes3/data_148.csv succeeded
# ./Changes3/data_1344.csv succeeded
# ./Changes3/data_1422.csv succeeded
# ./Changes3/data_1436.csv succeeded
# ./Changes3/data_809.csv succeeded
# ./Changes3/data_13.csv succeeded
# ./Changes3/data_1350.csv succeeded
# ./Changes3/data_1378.csv succeeded
# ./Changes3/data_821.csv succeeded
# ./Changes3/data_835.csv succeeded
# ./Changes3/data_772.csv succeeded
# ./Changes3/data_766.csv succeeded
# ./Changes3/data_996.csv succeeded
# ./Changes3/data_982.csv succeeded
# ./Changes3/data_1230.csv succeeded
# ./Changes3/data_969.csv succeeded
# ./Changes3/data_1224.csv succeeded
# ./Changes3/data_955.csv succeeded
# ./Changes3/data_941.csv succeeded
# ./Changes3/data_799.csv succeeded
# ./Changes3/data_1218.csv succeeded
# ./Changes3/data_570.csv succeeded
# ./Changes3/data_216.csv succeeded
# ./Changes3/data_202.csv succeeded
# ./Changes3/data_564.csv succeeded
# ./Changes3/data_558.csv succeeded
# ./Changes3/data_1032.csv succeeded
# ./Changes3/data_1026.csv succeeded
# ./Changes3/data_1027.csv succeeded
# ./Changes3/data_1033.csv succeeded
# ./Changes3/data_559.csv succeeded
# ./Changes3/data_203.csv succeeded
# ./Changes3/data_565.csv succeeded
# ./Changes3/data_571.csv succeeded
# ./Changes3/data_217.csv succeeded
# ./Changes3/data_798.csv succeeded
# ./Changes3/data_940.csv succeeded
# ./Changes3/data_1219.csv succeeded
# ./Changes3/data_954.csv succeeded
# ./Changes3/data_1225.csv succeeded
# ./Changes3/data_1231.csv succeeded
# ./Changes3/data_968.csv succeeded
# ./Changes3/data_983.csv succeeded
# ./Changes3/data_997.csv succeeded
# ./Changes3/data_767.csv succeeded
# ./Changes3/data_773.csv succeeded
# ./Changes3/data_834.csv succeeded
# ./Changes3/data_1379.csv succeeded
# ./Changes3/data_820.csv succeeded
# ./Changes3/data_808.csv succeeded
# ./Changes3/data_1437.csv succeeded
# ./Changes3/data_1351.csv succeeded
# ./Changes3/data_12.csv succeeded
# ./Changes3/data_1345.csv succeeded
# ./Changes3/data_1423.csv succeeded
# ./Changes3/data_149.csv succeeded
# ./Changes3/data_613.csv succeeded
# ./Changes3/data_1392.csv succeeded
# ./Changes3/data_175.csv succeeded
# ./Changes3/data_1386.csv succeeded
# ./Changes3/data_161.csv succeeded
# ./Changes3/data_607.csv succeeded
# ./Changes3/data_388.csv succeeded
# ./Changes3/data_1153.csv succeeded
# ./Changes3/data_1147.csv succeeded
# ./Changes3/data_439.csv succeeded
# ./Changes3/data_377.csv succeeded
# ./Changes3/data_1190.csv succeeded
# ./Changes3/data_411.csv succeeded
# ./Changes3/data_405.csv succeeded
# ./Changes3/data_363.csv succeeded
# ./Changes3/data_1184.csv succeeded
# ./Changes3/data_413.csv succeeded
# ./Changes3/data_1192.csv succeeded
# ./Changes3/data_375.csv succeeded
# ./Changes3/data_1186.csv succeeded
# ./Changes3/data_361.csv succeeded
# ./Changes3/data_407.csv succeeded
# ./Changes3/data_349.csv succeeded
# ./Changes3/data_1151.csv succeeded
# ./Changes3/data_1145.csv succeeded
# ./Changes3/data_1179.csv succeeded
# ./Changes3/data_177.csv succeeded
# ./Changes3/data_1390.csv succeeded
# ./Changes3/data_611.csv succeeded
# ./Changes3/data_605.csv succeeded
# ./Changes3/data_163.csv succeeded
# ./Changes3/data_1384.csv succeeded
# ./Changes3/data_8.csv succeeded
# ./Changes3/data_639.csv succeeded
# ./Changes3/data_10.csv succeeded
# ./Changes3/data_1353.csv succeeded
# ./Changes3/data_1435.csv succeeded
# ./Changes3/data_1421.csv succeeded
# ./Changes3/data_1347.csv succeeded
# ./Changes3/data_188.csv succeeded
# ./Changes3/data_1409.csv succeeded
# ./Changes3/data_836.csv succeeded
# ./Changes3/data_822.csv succeeded
# ./Changes3/data_38.csv succeeded
# ./Changes3/data_765.csv succeeded
# ./Changes3/data_771.csv succeeded
# ./Changes3/data_759.csv succeeded
# ./Changes3/data_981.csv succeeded
# ./Changes3/data_995.csv succeeded
# ./Changes3/data_1227.csv succeeded
# ./Changes3/data_1233.csv succeeded
# ./Changes3/data_942.csv succeeded
# ./Changes3/data_956.csv succeeded
# ./Changes3/data_567.csv succeeded
# ./Changes3/data_201.csv succeeded
# ./Changes3/data_215.csv succeeded
# ./Changes3/data_573.csv succeeded
# ./Changes3/data_229.csv succeeded
# ./Changes3/data_1025.csv succeeded
# ./Changes3/data_1031.csv succeeded
# ./Changes3/data_598.csv succeeded
# ./Changes3/data_1019.csv succeeded
# ./Changes3/data_599.csv succeeded
# ./Changes3/data_1018.csv succeeded
# ./Changes3/data_1030.csv succeeded
# ./Changes3/data_1024.csv succeeded
# ./Changes3/data_228.csv succeeded
# ./Changes3/data_214.csv succeeded
# ./Changes3/data_572.csv succeeded
# ./Changes3/data_566.csv succeeded
# ./Changes3/data_200.csv succeeded
# ./Changes3/data_957.csv succeeded
# ./Changes3/data_943.csv succeeded
# ./Changes3/data_1232.csv succeeded
# ./Changes3/data_1226.csv succeeded
# ./Changes3/data_994.csv succeeded
# ./Changes3/data_980.csv succeeded
# ./Changes3/data_758.csv succeeded
# ./Changes3/data_770.csv succeeded
# ./Changes3/data_764.csv succeeded
# ./Changes3/data_823.csv succeeded
# ./Changes3/data_39.csv succeeded
# ./Changes3/data_189.csv succeeded
# ./Changes3/data_837.csv succeeded
# ./Changes3/data_1408.csv succeeded
# ./Changes3/data_1420.csv succeeded
# ./Changes3/data_1346.csv succeeded
# ./Changes3/data_1352.csv succeeded
# ./Changes3/data_11.csv succeeded
# ./Changes3/data_1434.csv succeeded
# ./Changes3/data_638.csv succeeded
# ./Changes3/data_9.csv succeeded
# ./Changes3/data_604.csv succeeded
# ./Changes3/data_1385.csv succeeded
# ./Changes3/data_162.csv succeeded
# ./Changes3/data_1391.csv succeeded
# ./Changes3/data_176.csv succeeded
# ./Changes3/data_610.csv succeeded
# ./Changes3/data_1178.csv succeeded
# ./Changes3/data_1144.csv succeeded
# ./Changes3/data_1150.csv succeeded
# ./Changes3/data_348.csv succeeded
# ./Changes3/data_360.csv succeeded
# ./Changes3/data_1187.csv succeeded
# ./Changes3/data_406.csv succeeded
# ./Changes3/data_412.csv succeeded
# ./Changes3/data_374.csv succeeded
# ./Changes3/data_1193.csv succeeded
# ./Changes3/data_358.csv succeeded
# ./Changes3/data_370.csv succeeded
# ./Changes3/data_1197.csv succeeded
# ./Changes3/data_416.csv succeeded
# ./Changes3/data_402.csv succeeded
# ./Changes3/data_364.csv succeeded
# ./Changes3/data_1183.csv succeeded
# ./Changes3/data_1168.csv succeeded
# ./Changes3/data_1154.csv succeeded
# ./Changes3/data_1140.csv succeeded
# ./Changes3/data_628.csv succeeded
# ./Changes3/data_614.csv succeeded
# ./Changes3/data_1395.csv succeeded
# ./Changes3/data_172.csv succeeded
# ./Changes3/data_1381.csv succeeded
# ./Changes3/data_166.csv succeeded
# ./Changes3/data_600.csv succeeded
# ./Changes3/data_833.csv succeeded
# ./Changes3/data_29.csv succeeded
# ./Changes3/data_199.csv succeeded
# ./Changes3/data_1418.csv succeeded
# ./Changes3/data_827.csv succeeded
# ./Changes3/data_1430.csv succeeded
# ./Changes3/data_15.csv succeeded
# ./Changes3/data_1356.csv succeeded
# ./Changes3/data_1342.csv succeeded
# ./Changes3/data_1424.csv succeeded
# ./Changes3/data_984.csv succeeded
# ./Changes3/data_748.csv succeeded
# ./Changes3/data_990.csv succeeded
# ./Changes3/data_760.csv succeeded
# ./Changes3/data_774.csv succeeded
# ./Changes3/data_947.csv succeeded
# ./Changes3/data_953.csv succeeded
# ./Changes3/data_1222.csv succeeded
# ./Changes3/data_1236.csv succeeded
# ./Changes3/data_238.csv succeeded
# ./Changes3/data_204.csv succeeded
# ./Changes3/data_562.csv succeeded
# ./Changes3/data_576.csv succeeded
# ./Changes3/data_210.csv succeeded
# ./Changes3/data_589.csv succeeded
# ./Changes3/data_1008.csv succeeded
# ./Changes3/data_1020.csv succeeded
# ./Changes3/data_1034.csv succeeded
# ./Changes3/data_1035.csv succeeded
# ./Changes3/data_1021.csv succeeded
# ./Changes3/data_588.csv succeeded
# ./Changes3/data_1009.csv succeeded
# ./Changes3/data_577.csv succeeded
# ./Changes3/data_211.csv succeeded
# ./Changes3/data_205.csv succeeded
# ./Changes3/data_563.csv succeeded
# ./Changes3/data_239.csv succeeded
# ./Changes3/data_1237.csv succeeded
# ./Changes3/data_1223.csv succeeded
# ./Changes3/data_952.csv succeeded
# ./Changes3/data_946.csv succeeded
# ./Changes3/data_775.csv succeeded
# ./Changes3/data_761.csv succeeded
# ./Changes3/data_991.csv succeeded
# ./Changes3/data_749.csv succeeded
# ./Changes3/data_985.csv succeeded
# ./Changes3/data_1343.csv succeeded
# ./Changes3/data_1425.csv succeeded
# ./Changes3/data_1431.csv succeeded
# ./Changes3/data_1357.csv succeeded
# ./Changes3/data_14.csv succeeded
# ./Changes3/data_198.csv succeeded
# ./Changes3/data_826.csv succeeded
# ./Changes3/data_1419.csv succeeded
# ./Changes3/data_832.csv succeeded
# ./Changes3/data_28.csv succeeded
# ./Changes3/data_167.csv succeeded
# ./Changes3/data_1380.csv succeeded
# ./Changes3/data_601.csv succeeded
# ./Changes3/data_615.csv succeeded
# ./Changes3/data_173.csv succeeded
# ./Changes3/data_1394.csv succeeded
# ./Changes3/data_629.csv succeeded
# ./Changes3/data_1141.csv succeeded
# ./Changes3/data_1155.csv succeeded
# ./Changes3/data_1169.csv succeeded
# ./Changes3/data_403.csv succeeded
# ./Changes3/data_1182.csv succeeded
# ./Changes3/data_365.csv succeeded
# ./Changes3/data_1196.csv succeeded
# ./Changes3/data_371.csv succeeded
# ./Changes3/data_417.csv succeeded
# ./Changes3/data_359.csv succeeded
# ./Changes3/data_429.csv succeeded
# ./Changes3/data_367.csv succeeded
# ./Changes3/data_1180.csv succeeded
# ./Changes3/data_401.csv succeeded
# ./Changes3/data_415.csv succeeded
# ./Changes3/data_373.csv succeeded
# ./Changes3/data_1194.csv succeeded
# ./Changes3/data_398.csv succeeded
# ./Changes3/data_1143.csv succeeded
# ./Changes3/data_1157.csv succeeded
# ./Changes3/data_159.csv succeeded
# ./Changes3/data_603.csv succeeded
# ./Changes3/data_1382.csv succeeded
# ./Changes3/data_165.csv succeeded
# ./Changes3/data_1396.csv succeeded
# ./Changes3/data_171.csv succeeded
# ./Changes3/data_617.csv succeeded
# ./Changes3/data_824.csv succeeded
# ./Changes3/data_1369.csv succeeded
# ./Changes3/data_830.csv succeeded
# ./Changes3/data_1427.csv succeeded
# ./Changes3/data_818.csv succeeded
# ./Changes3/data_1341.csv succeeded
# ./Changes3/data_16.csv succeeded
# ./Changes3/data_1355.csv succeeded
# ./Changes3/data_1433.csv succeeded
# ./Changes3/data_993.csv succeeded
# ./Changes3/data_987.csv succeeded
# ./Changes3/data_777.csv succeeded
# ./Changes3/data_763.csv succeeded
# ./Changes3/data_950.csv succeeded
# ./Changes3/data_788.csv succeeded
# ./Changes3/data_1209.csv succeeded
# ./Changes3/data_944.csv succeeded
# ./Changes3/data_1235.csv succeeded
# ./Changes3/data_1221.csv succeeded
# ./Changes3/data_978.csv succeeded
# ./Changes3/data_549.csv succeeded
# ./Changes3/data_213.csv succeeded
# ./Changes3/data_575.csv succeeded
# ./Changes3/data_561.csv succeeded
# ./Changes3/data_207.csv succeeded
# ./Changes3/data_1037.csv succeeded
# ./Changes3/data_1023.csv succeeded
# ./Changes3/data_1022.csv succeeded
# ./Changes3/data_1036.csv succeeded
# ./Changes3/data_560.csv succeeded
# ./Changes3/data_206.csv succeeded
# ./Changes3/data_212.csv succeeded
# ./Changes3/data_574.csv succeeded
# ./Changes3/data_548.csv succeeded
# ./Changes3/data_1220.csv succeeded
# ./Changes3/data_979.csv succeeded
# ./Changes3/data_1234.csv succeeded
# ./Changes3/data_945.csv succeeded
# ./Changes3/data_789.csv succeeded
# ./Changes3/data_951.csv succeeded
# ./Changes3/data_1208.csv succeeded
# ./Changes3/data_762.csv succeeded
# ./Changes3/data_776.csv succeeded
# ./Changes3/data_986.csv succeeded
# ./Changes3/data_992.csv succeeded
# ./Changes3/data_1354.csv succeeded
# ./Changes3/data_17.csv succeeded
# ./Changes3/data_1432.csv succeeded
# ./Changes3/data_819.csv succeeded
# ./Changes3/data_1426.csv succeeded
# ./Changes3/data_1340.csv succeeded
# ./Changes3/data_1368.csv succeeded
# ./Changes3/data_831.csv succeeded
# ./Changes3/data_825.csv succeeded
# ./Changes3/data_170.csv succeeded
# ./Changes3/data_1397.csv succeeded
# ./Changes3/data_616.csv succeeded
# ./Changes3/data_602.csv succeeded
# ./Changes3/data_164.csv succeeded
# ./Changes3/data_1383.csv succeeded
# ./Changes3/data_158.csv succeeded
# ./Changes3/data_1156.csv succeeded
# ./Changes3/data_1142.csv succeeded
# ./Changes3/data_399.csv succeeded
# ./Changes3/data_414.csv succeeded
# ./Changes3/data_1195.csv succeeded
# ./Changes3/data_372.csv succeeded
# ./Changes3/data_1181.csv succeeded
# ./Changes3/data_366.csv succeeded
# ./Changes3/data_400.csv succeeded
# ./Changes3/data_428.csv succeeded

# %%
df.dropna(axis=1, inplace=True)

# %%
df.loc[(df["description_length"]==325)&(df["is_dependent"]==1), ["number", "description_length"]]

# %%
dep_per_project = df.groupby(['project', 'is_dependent']).count().reset_index()[['project', 'is_dependent', 'number']]
dep_per_project.rename(columns={'number': 'count'}, inplace=True)
# dep_per_project[(dep_per_project['is_dependent']==1)&(dep_per_project['count']==0)]
projects_sample = dep_per_project.sort_values(['is_dependent', 'count'], ascending=False)
projects_sample = projects_sample[(projects_sample['is_dependent']==1)&(projects_sample['count']>=300)].iloc[:, 0].unique()

# %% [markdown]
# ### Build dataset for the 1st model

# %%
y = df['is_dependent']
X = df.drop(columns=['is_dependent'])

# %% [markdown]
# ### Base estimators

# %%
ensemble_classifiers = clas_util.load_classifiers()

# %%
df_features = pd.read_csv(osp.join(".", "Results", "Correlation", "first_model.csv"))

# %% [markdown]
# ### Training ad evaluation of the first and second model

# %%
training_results = {key: None for key in ensemble_classifiers.keys()}
tscv = TimeSeriesSplit(n_splits = 10)

clf_path = osp.join('.', 'Results')
if not os.path.exists(clf_path):
    os.makedirs(clf_path)

df_feat_impo = pd.DataFrame()
# df_feat_impact = pd.DataFrame()

for label, ens_clf in ensemble_classifiers.items():
    print(f'Start training with {label} classifier...')

    # if label not in ['RF']:
    #     continue

    auc_scores = []
    precision_scores = []
    recall_scores = []
    brier_scores = []
    # feature_importances = np.zeros(len(METRICS))
    feature_importances = []
    corr_features = []
    redundant_features = []
    # df_features = pd.DataFrame({"Feat":X_train.columns.tolist()})
    # for f in range(0, 10):
    #     df_features[f"Fold{f}"] = [1]*len(df_features)
    # df_features.to_csv(osp.join(".", "Results", "Correlation", "first_model.csv"), index=None)

    for fold, (train_idx, test_idx) in enumerate(tscv.split(X)):
        # if fold < 7:
        #     continue
        clone_clf = clone(ens_clf)

        # Filter training set
        X_train = X.iloc[train_idx]
        y_train = y.iloc[train_idx]
        
        # corr_path = osp.join('.', 'Results', 'Correlation', f'first_model')
        # if not os.path.exists(corr_path):
        #     os.makedirs(corr_path)
            
        corr_features = df_features.loc[df_features[f'Fold{fold}']==0, 'Feat'].tolist()
        # plt.figure(figsize=(6,12))
        # dissimilarity = 1 - abs(X_train.corr())
        # Z = linkage(squareform(dissimilarity), 'complete')

        # dendrogram(Z, labels=X_train.columns, orientation='left')

        # threshold = 0.3 * max(Z[:, 2])  # Scale threshold based on the maximum distance in the dendrogram
        # plt.axvline(x=threshold, color='r', linestyle='--')

        # # Adjust the layout to make sure labels fit
        # plt.tight_layout()
        # plt.savefig(f'{corr_path}/{fold}.pdf')

        # Remove highly correlated features from the training sets
        if len(corr_features) > 0:
            X_train = X_train.drop(columns=corr_features, errors='ignore')

        # Conduct redundancy analysis
        redundant_features = clas_util.redundancy_analysis(X_train)

        # Remove indepandent variables explained by others
        X_train = X_train.drop(columns=redundant_features)

        # Instantiate the UnderSampler class then fit it on the each fold training dataset
        ros = RandomUnderSampler(random_state=0)
        
        # Perform under-sampling of the majority class(es)
        X_train, y_train = ros.fit_resample(X_train, y_train)
    
        # Train the Random Forest Classifier on the training fold set 
        clone_clf.fit(X_train, y_train)

        # Columns to exclude in the test set
        cols_exluded = corr_features + redundant_features
        
        # print(highly_correlated_features, independent_features)

        # Filter training set
        X_test = X.iloc[test_idx]
        X_test = X_test.drop(columns=cols_exluded, errors='ignore')
        y_test = y.iloc[test_idx]

        # Test the Random Forest Classifier on the test fold set 
        y_pred = clone_clf.predict(X_test)
        
        precision_scores.append(precision_score(y_test, y_pred))
        recall_scores.append(recall_score(y_test, y_pred))
        auc_scores.append(roc_auc_score(y_test, y_pred))
        brier_scores.append(brier_score_loss(y_test, y_pred))

        # if label == 'RF':
        #     df_feat_imp_item = pd.DataFrame({name: [val] for name, val in zip(X_train.columns.to_list(), clone_clf.feature_importances_)})
        #     # if 'pctg_mod_file_dep_cha' in X_train.columns:
        #     # print(X_train.columns.sort_values())
        #     df_feat_impo = pd.concat((df_feat_impo, df_feat_imp_item))
        # if label not in ['MLP']:

        #     binary_cols = list(constants.DESCRIPTION.keys())

        #     # Step 1: Calculate the median of each column
        #     medians = X_train.median()

        #     # Step 2: Calculate the standard deviation of each column
        #     std_devs = X_train.std()

        #     # Step 3: Create a new dataframe starting with the median row
        #     df_feat_impact_item = pd.DataFrame([medians])
        #     for col in binary_cols:
        #         if col in X_train.columns.tolist():
        #             df_feat_impact_item[col] = 0
        
        #     df_feat_impact_item = pd.concat([df_feat_impact_item] * (len(X_train.columns.to_list()) + 1), ignore_index=True)

        #     # Step 4: Double the number of rows according to the number of features and add standard deviation to each column
        #     for idx, col in zip(range(1, len(df_feat_impact_item.columns)+1), df_feat_impact_item.columns):
        #         if col in binary_cols:
        #             df_feat_impact_item.iloc[idx, idx-1] = 1
        #         else:
        #             df_feat_impact_item.iloc[idx, idx-1] += std_devs[col]

        #     df_feat_impact_item['pred'] = clone_clf.predict_proba(df_feat_impact_item)[:,1]
        #     proba1 = df_feat_impact_item.iloc[0, -1]
        #     df_feat_impact_item['impact'] = None

        #     df_feat_impact_item.iloc[1:, -1] = 0 if proba1 == 0 else (df_feat_impact_item.iloc[1:, -2] - proba1) / proba1

        #     df_feat_impact_item['fold'] = fold
        #     df_feat_impact_item['Classifier'] = label

        #     df_feat_impact = pd.concat((df_feat_impact, df_feat_impact_item))

        print(f"{label}, Fold: {fold+1}, Precision: {precision_scores[-1]}, Recall: {recall_scores[-1]}, AUC: {auc_scores[-1]}, Brier: {brier_scores[-1]}")

    prec_avg = np.average(precision_scores)
    recall_avg = np.average(recall_scores)
    auc_avg = np.average(auc_scores)
    brier_avg = np.average(brier_scores)

    print(f"{label}, Precision: {prec_avg}, Recall: {recall_avg}, AUC: {auc_avg}, Brier: {brier_avg}")

    training_results[label] = {
        'Classifier': label,
        'Precision': prec_avg,
        'Recall': recall_avg,
        'AUC': auc_avg,
        'Brier': brier_avg,
        'AUC Scores': auc_scores,
        'Precision Scores': precision_scores,
        'Recall Scores': recall_scores,
        'Brier Scores': brier_scores,
        # 'feature_importances': feature_importances,
        # 'features': X_train.columns.tolist()
    }

# %%
df_training_results = pd.DataFrame(list(training_results.values()))
df_training_results.sort_values(by=['AUC', 'Brier'], ascending=[0, 1], inplace=True)
df_training_results.to_csv(osp.join('.', 'Results', 'first_model_perf.csv'), index=None)

# %%
df_training_results = pd.read_csv(osp.join('.', 'Results', 'first_model_perf.csv'))
# df_training_results.sort_values(by=['AUC', 'Brier'], ascending=False, inplace=True)

# %%
def latex_float(f):
    float_str = "{0:.2g}".format(f)
    if "e" in float_str:
        base, exponent = float_str.split("e")
        return r"{0} \times 10^{{{1}}}".format(base, int(exponent))
    else:
        return float_str

# %%
df_training_results_m2 = pd.read_csv(osp.join(".", "Results", "second_model_perf.csv"))

# %%
for idx, row in df_training_results.iterrows():
    m2_perf = df_training_results_m2[df_training_results_m2['Classifier']==row['Classifier']]
    print("\multirow{2}{*}"+"{"+row['Classifier']+"} & AUC & $"+str(round(row['AUC']*100, 2))+"\%$ & $"+str(round(m2_perf['AUC'].values[0]*100, 2))+"\%$\\" + "\\")
    print("& Brier & $"+latex_float(row['Brier'])+"$ & $"+latex_float(m2_perf['Brier'].values[0])+"$\\"+ "\\")
    print("\\noalign{\smallskip}")
    print("\hhline{~----}")

    print("\\noalign{\smallskip}")
# Out:
# \multirow{2}{*}{RF} & AUC & $82.86\%$ & $80.84\%$\\
# & Brier & $0.28$ & $0.072$\\
# \noalign{\smallskip}
# \hhline{~----}
# \noalign{\smallskip}
# \multirow{2}{*}{AdaBoost} & AUC & $82.72\%$ & $77.16\%$\\
# & Brier & $0.27$ & $0.16$\\
# \noalign{\smallskip}
# \hhline{~----}
# \noalign{\smallskip}
# \multirow{2}{*}{XGBoost} & AUC & $82.35\%$ & $84.49\%$\\
# & Brier & $0.26$ & $0.099$\\
# \noalign{\smallskip}
# \hhline{~----}
# \noalign{\smallskip}
# \multirow{2}{*}{ET} & AUC & $70.74\%$ & $64.49\%$\\
# & Brier & $0.35$ & $0.3$\\
# \noalign{\smallskip}
# \hhline{~----}
# \noalign{\smallskip}
# \multirow{2}{*}{MLP} & AUC & $60.02\%$ & $69.58\%$\\
# & Brier & $0.61$ & $0.17$\\
# \noalign{\smallskip}
# \hhline{~----}
# \noalign{\smallskip}

# %%
df_feat_impact = df_feat_impact.reset_index(drop=True)
# df_feat_impact.to_csv(osp.join('.', 'Results', 'Impact', 'first_model_feat_impact.csv'), index=None)
# Out:
#      has_feature_addition  deletions  insertions  num_file_types  \
# 0                       0    2.00000   13.000000        1.000000
# 1                       1    2.00000   13.000000        1.000000
# 2                       0   12.89036   13.000000        1.000000
# 3                       0    2.00000  239.808907        1.000000
# 4                       0    2.00000   13.000000        1.637287
# ..                    ...        ...         ...             ...
# 235                     0    2.00000    7.000000        1.000000
# 236                     0    2.00000    7.000000        1.000000
# 237                     0    2.00000    7.000000        1.000000
# 238                     0    2.00000    7.000000        1.000000
# 239                     0    2.00000    7.000000        1.000000
#
#      is_preventive  project_changes_owner  is_refactoring  \
# 0                0                    5.0               0
# 1                0                    5.0               0
# 2                0                    5.0               0
# 3                0                    5.0               0
# 4                0                    5.0               0
# ..             ...                    ...             ...
# 235              0                    NaN               0
# 236              0                    NaN               0
# 237              0                    NaN               0
# 238              0                    NaN               0
# 239              0                    NaN               0
#
#      whole_within_project_changes  is_merge  num_directory_files  ...  \
# 0                             7.5         0                  1.0  ...
# 1                             7.5         0                  1.0  ...
# 2                             7.5         0                  1.0  ...
# 3                             7.5         0                  1.0  ...
# 4                             7.5         0                  1.0  ...
# ..                            ...       ...                  ...  ...
# 235                       15357.0         0                  1.0  ...
# 236                       15357.0         0                  1.0  ...
# 237                       15357.0         0                  1.0  ...
# 238                       15357.0         0                  1.0  ...
# 239                       15357.0         0                  1.0  ...
#
#      pctg_mod_file_dep_cha  pred    impact  fold  max_num_mod_file_dep_cha  \
# 0                 0.000000  0.12      None     1                       NaN
# 1                 0.000000  0.13  0.083333     1                       NaN
# 2                 0.000000  0.09     -0.25     1                       NaN
# 3                 0.000000  0.18       0.5     1                       NaN
# 4                 0.000000  0.12       0.0     1                       NaN
# ..                     ...   ...       ...   ...                       ...
# 235              60.000000  0.58  0.074074    10                       NaN
# 236              60.000000  0.55  0.018519    10                       NaN
# 237              60.000000  0.61   0.12963    10                       NaN
# 238              60.000000  0.62  0.148148    10                       NaN
# 239             105.949923  0.60  0.111111    10                       NaN
#
#      cross_project_changes_owner  min_num_mod_file_dep_cha  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ..                           ...                       ...
# 235                          1.0                  0.000000
# 236                          1.0                  0.000000
# 237                          1.0                  0.000000
# 238                          1.0                 74.604505
# 239                          1.0                  0.000000
#
#      cross_project_changes  whole_changes_owner  num_dev_modified_files
# 0                      NaN                  NaN                     NaN
# 1                      NaN                  NaN                     NaN
# 2                      NaN                  NaN                     NaN
# 3                      NaN                  NaN                     NaN
# 4                      NaN                  NaN                     NaN
# ..                     ...                  ...                     ...
# 235                   42.0                389.0                     NaN
# 236                   42.0                389.0                     NaN
# 237                   42.0                389.0                     NaN
# 238                   42.0                389.0                     NaN
# 239                   42.0                389.0                     NaN
#
# [240 rows x 31 columns]

# %% [markdown]
# ### Feature importance

# %%
df_feat_impo.fillna(0, inplace=True)
# df_feat_impo
df_feat_impo.to_csv(osp.join('.', 'Results', 'Feature_importance', 'first_feat_impo.csv'), index=None)

# %% [markdown]
# ### Dimension importance

# %%
dimensions = {
    'Change': constants.CHANGE_METRICS,
    'Text': constants.TEXT_METRICS,
    'Developer': constants.DEVELOPER_METRICS,
    'Project': constants.PROJECT_METRICS,
    'File': constants.FILE_METRICS
}

# %%
dimension_results = {key: [] for key in dimensions.keys()}
# Change variable to 'keep' or 'discard
dimension_type = 'keep'

tscv = TimeSeriesSplit(n_splits = 10)

clf_path = osp.join('.', 'Results')
if not os.path.exists(clf_path):
    os.makedirs(clf_path)

for label, dimension in dimensions.items():
    print(f'Start training with {label} dimension...')

    features = []
    if dimension_type == 'keep':
        features = dimension
    else:
        for lab, dim in dimensions.items():
            if lab != label:
                features += dim

    features = [f for f in features if f in X.columns.tolist()]

    auc_scores = []
    precision_scores = []
    recall_scores = []
    brier_scores = []
    
    feature_importances = []

    kept_feat = []
    corr_features = []
    redundant_features = []

    for fold, (train_idx, test_idx) in enumerate(tscv.split(X)):

        forest_clf = RandomForestClassifier(random_state=42)

        # Filter training set
        X_train = X.iloc[train_idx]
        X_train = X_train[features]
        y_train = y.iloc[train_idx]

        # conduct the correlation analysis

        # if fold == 0:
        # corr_path = osp.join('.', 'Results', 'Correlation', f'{model}_model')
            
        corr_features = df_features.loc[df_features[f'Fold{fold}']==0, 'Feat'].tolist()
        # corr_features = clas_util.correlation_analysis(X_train, metric_imp)

        features = [f for f in features if f not in corr_features]
        # # Remove highly correlated features from the training set
        X_train = X_train[features]

        # Conduct redundancy analysis
        # if fold == 0 and len(features) > 1:
        redundant_features = clas_util.redundancy_analysis(X_train)
            # features = [f for f in features if f not in corr_features]

        # Remove indepandent variables explained by others
        if len(redundant_features) != 0:
            X_train = X_train.drop(columns=redundant_features)

        # Instantiate the UnderSampler class then fit it on the each fold training dataset
        ros = RandomUnderSampler(random_state=0)

        # Perform under-sampling of the majority class(es)
        X_train, y_train = ros.fit_resample(X_train, y_train)
    
        # Train the Random Forest Classifier on the training fold set 
        forest_clf.fit(X_train, y_train)

        # Filter training set
        X_test = X.iloc[test_idx]
        X_test = X_test[X_train.columns.tolist()]
        y_test = y.iloc[test_idx]

        # Test the Random Forest Classifier on the test fold set 
        y_pred = forest_clf.predict(X_test)

        precision = precision_score(y_test, y_pred)
        recall = recall_score(y_test, y_pred)
        auc = roc_auc_score(y_test, y_pred)
        brier = brier_score_loss(y_test, y_pred)

        precision_scores.append(precision)
        recall_scores.append(recall)
        auc_scores.append(auc)
        brier_scores.append(brier)

        # feature_importances.app

        print(f"Dimension: {label}, Fold: {fold+1}, Precision: {precision}, Recall: {recall}, AUC: {auc}, Brier: {brier}")

        kept_feat = X_train.columns.tolist()

    prec_avg = np.average(precision_scores)
    recall_avg = np.average(recall_scores)
    auc_avg = np.average(auc_scores)
    brier_avg = np.average(brier_scores)

    print(f"{label}, Precision: {prec_avg}, Recall: {recall_avg}, AUC: {auc_avg}")
    dimension_results[label] += [{
        'Dimension': label,
        'Precision': prec_avg,
        'Recall': recall_avg,
        'AUC': auc_avg,
        'Brier': brier_avg
    }]
# Out:
# Start training with Change dimension...
# Dimension: Change, Fold: 1, Precision: 0.015423621381787449, Recall: 0.35138387484957884, AUC: 0.5298755534207842, Brier: 0.2962144964245448
# Dimension: Change, Fold: 2, Precision: 0.05910109708623334, Recall: 0.5084573748308525, AUC: 0.5606082572556943, Brier: 0.39200271827266125
# Dimension: Change, Fold: 3, Precision: 0.06943020916372471, Recall: 0.5462962962962963, AUC: 0.5735194897009421, Brier: 0.4020726829042272
# Dimension: Change, Fold: 4, Precision: 0.07304228362082126, Recall: 0.5445234708392603, AUC: 0.5739177322840148, Brier: 0.3998795310979659
# Dimension: Change, Fold: 5, Precision: 0.0955488938640762, Recall: 0.5478677110530896, AUC: 0.5758074735877574, Brier: 0.40021931518062615
# Dimension: Change, Fold: 6, Precision: 0.1363697388735987, Recall: 0.5768848502058782, AUC: 0.5654856110172605, Brier: 0.44343367260259164
# Dimension: Change, Fold: 7, Precision: 0.11440801990340992, Recall: 0.5274076572777872, AUC: 0.5579419870257819, Brier: 0.4171158509274561
# Dimension: Change, Fold: 8, Precision: 0.11243826403726925, Recall: 0.5262295081967213, AUC: 0.5470849486522168, Brier: 0.43598931224612725
# Dimension: Change, Fold: 9, Precision: 0.11693564067664787, Recall: 0.5245987438939288, AUC: 0.5699076071414064, Brier: 0.39280584428622173
# Dimension: Change, Fold: 10, Precision: 0.0873059866962306, Recall: 0.5353241077931536, AUC: 0.5775601207963591, Brier: 0.38557771016417747
# Change, Precision: 0.08800037553037993, Recall: 0.5188973595236547, AUC: 0.5631708780882216
# Start training with Text dimension...
# Dimension: Text, Fold: 1, Precision: 0.014331845724030333, Recall: 0.4753309265944645, AUC: 0.5251521645926825, Brier: 0.42630546589031154
# Dimension: Text, Fold: 2, Precision: 0.059796588705528515, Recall: 0.5111637347767253, AUC: 0.5633370420901801, Brier: 0.38925355614931967
# Dimension: Text, Fold: 3, Precision: 0.07263809412589046, Recall: 0.557347670250896, AUC: 0.5846723041558883, Brier: 0.3908289187143806
# Dimension: Text, Fold: 4, Precision: 0.07982815057283142, Recall: 0.5550497866287339, AUC: 0.5938872528649288, Brier: 0.3714921154648092
# Dimension: Text, Fold: 5, Precision: 0.10417749350389766, Recall: 0.5670147954743255, AUC: 0.5972345178182918, Brier: 0.3768359924011923
# Dimension: Text, Fold: 6, Precision: 0.14939333608805078, Recall: 0.5646741445406787, AUC: 0.5861288371393258, Brier: 0.39708403478153426
# Dimension: Text, Fold: 7, Precision: 0.12211854092132925, Recall: 0.5584415584415584, AUC: 0.5768847596349382, Brier: 0.40804979381284073
# Dimension: Text, Fold: 8, Precision: 0.12108932939072026, Recall: 0.5437704918032787, AUC: 0.5666232546659411, Brier: 0.41483003073501473
# Dimension: Text, Fold: 9, Precision: 0.10817125970723662, Recall: 0.5491974877878576, AUC: 0.5547054964144744, Brier: 0.44076173413440006
# Dimension: Text, Fold: 10, Precision: 0.08553299492385787, Recall: 0.5727118232580724, AUC: 0.5783579568886522, Brier: 0.4167142879206759
# Text, Precision: 0.09170776336633732, Recall: 0.5454702419556592, AUC: 0.5726983586265304
# Start training with Developer dimension...
# Dimension: Developer, Fold: 1, Precision: 0.16494192185850054, Recall: 0.9398315282791817, AUC: 0.9389845419104151, Brier: 0.06184070304415649
# Dimension: Developer, Fold: 2, Precision: 0.15852524478967234, Recall: 0.9803788903924222, AUC: 0.8657133888125953, Brier: 0.2384820918343707
# Dimension: Developer, Fold: 3, Precision: 0.14283827220289727, Recall: 0.9689366786140979, AUC: 0.8259396987754443, Brier: 0.3022688309883083
# Dimension: Developer, Fold: 4, Precision: 0.1609031432928329, Recall: 0.9305832147937411, AUC: 0.8260016936262929, Brier: 0.2672247362812177
# Dimension: Developer, Fold: 5, Precision: 0.16187008105250794, Recall: 0.8994778067885117, AUC: 0.7718116868891272, Brier: 0.3377299334332093
# Dimension: Developer, Fold: 6, Precision: 0.23289742232973012, Recall: 0.8749112594065029, AUC: 0.7615926046096705, Brier: 0.327073069022503
# Dimension: Developer, Fold: 7, Precision: 0.20258894833327099, Recall: 0.9133074717490302, AUC: 0.7754677043875553, Brier: 0.3371275889230389
# Dimension: Developer, Fold: 8, Precision: 0.17627906976744187, Recall: 0.8698360655737705, AUC: 0.7235346713191205, Brier: 0.39519977759587316
# Dimension: Developer, Fold: 9, Precision: 0.16958477508650519, Recall: 0.8550244242847174, AUC: 0.724182550192007, Brier: 0.3834926714751263
# Dimension: Developer, Fold: 10, Precision: 0.12769689528152955, Recall: 0.883709638261714, AUC: 0.73679280158121, Brier: 0.39143126322455096
# Developer, Precision: 0.16981257739948888, Recall: 0.911599697814369, AUC: 0.7950021342103437
# Start training with Project dimension...
# Dimension: Project, Fold: 1, Precision: 0.012834571485937573, Recall: 1.0, AUC: 0.5, Brier: 0.9871654285140624
# Dimension: Project, Fold: 2, Precision: 0.04752591433600626, Recall: 0.9042625169147497, AUC: 0.5186538912032439, Brier: 0.8317451001590808
# Dimension: Project, Fold: 3, Precision: 0.06377679265115854, Recall: 0.8336320191158901, AUC: 0.5831705104455817, Brier: 0.6413887902142185
# Dimension: Project, Fold: 4, Precision: 0.06826466654428155, Recall: 0.7405405405405405, AUC: 0.5801605237325123, Brier: 0.5628059987335321
# Dimension: Project, Fold: 5, Precision: 0.08781168862979474, Recall: 0.7800261096605744, AUC: 0.5804504540422704, Brier: 0.5907918513599085
# Dimension: Project, Fold: 6, Precision: 0.11113618413629696, Recall: 0.8391310521084765, AUC: 0.5099925328475281, Brier: 0.7475404265834711
# Dimension: Project, Fold: 7, Precision: 0.09998340524394292, Recall: 0.812953280485748, AUC: 0.5376439699718685, Brier: 0.6872441966423155
# Dimension: Project, Fold: 8, Precision: 0.1065891472868217, Recall: 0.55, AUC: 0.5352520163009191, Brier: 0.47671706797226127
# Dimension: Project, Fold: 9, Precision: 0.0925953241389483, Recall: 0.8761339846475925, AUC: 0.5211052029482138, Brier: 0.7710627519421749
# Dimension: Project, Fold: 10, Precision: 0.07656025868566288, Recall: 0.7645059480456421, AUC: 0.5690148662178465, Brier: 0.601603163080915
# Project, Precision: 0.07670779531388514, Recall: 0.8101185451519214, AUC: 0.5435443967709984
# Start training with File dimension...
# Dimension: File, Fold: 1, Precision: 0.015484842532573822, Recall: 0.5691937424789411, AUC: 0.5493427877548971, Brier: 0.4699986099742073
# Dimension: File, Fold: 2, Precision: 0.059037621638188646, Recall: 0.5213125845737483, AUC: 0.5619137569661964, Brier: 0.40119233323551673
# Dimension: File, Fold: 3, Precision: 0.06765880562951693, Recall: 0.4250298685782557, AUC: 0.5528299231325944, Brier: 0.3325868380002162
# Dimension: File, Fold: 4, Precision: 0.07265589440145653, Recall: 0.36330014224751067, AUC: 0.5485578970971026, Brier: 0.2862989791032789
# Dimension: File, Fold: 5, Precision: 0.08994515539305302, Recall: 0.32114882506527415, AUC: 0.536436825460103, Brier: 0.2788391740157845
# Dimension: File, Fold: 6, Precision: 0.13462425080682341, Recall: 0.331676842254721, AUC: 0.5357261238862681, Brier: 0.3046164301048697
# Dimension: File, Fold: 7, Precision: 0.1181812565639093, Recall: 0.32265137459942655, AUC: 0.5399852813015494, Brier: 0.2824841305388667
# Dimension: File, Fold: 8, Precision: 0.11205352935632834, Recall: 0.3898360655737705, AUC: 0.5342619037436265, Brier: 0.34852580042318565
# Dimension: File, Fold: 9, Precision: 0.10508567619495746, Recall: 0.4675505931612003, AUC: 0.5404092032145068, Brier: 0.3996324154014858
# Dimension: File, Fold: 10, Precision: 0.07687088405507883, Recall: 0.4675892206846322, AUC: 0.543049410104802, Brier: 0.39109147914189074
# File, Precision: 0.08515979165718862, Recall: 0.417928925921748, AUC: 0.5442513112661646

# %%
dim_imp = pd.DataFrame([item[0] for item in list(dimension_results.values())])
dim_imp.to_csv(osp.join('.', 'Results', 'Feature_importance', f'first_model_{dimension_type}_dim.csv'), index=None)

# %%
dim_imp
# Out:
#    Dimension  Precision    Recall       AUC     Brier
# 0     Change   0.184608  0.931897  0.819432  0.276269
# 1       Text   0.171462  0.941881  0.811367  0.299549
# 2  Developer   0.104390  0.860847  0.646060  0.541653
# 3    Project   0.176986  0.955364  0.817475  0.299555
# 4       File   0.180999  0.946864  0.821739  0.284503

# %%
def round_number(nbr):
    return round(100 * nbr, 2)

# %%
first_model_keep_dim = pd.read_csv(osp.join(".", "Results", "Feature_importance", "first_model_keep_dim.csv"))
first_model_discard_dim = pd.read_csv(osp.join(".", "Results", "Feature_importance", "first_model_discard_dim.csv"))
second_model_keep_dim = pd.read_csv(osp.join(".", "Results", "Feature_importance", "second_model_keep_dim.csv"))
second_model_discard_dim = pd.read_csv(osp.join(".", "Results", "Feature_importance", "second_model_discard_dim.csv"))

first_model_perf = pd.read_csv(osp.join(".", "Results", "first_model_perf.csv"))
second_model_perf = pd.read_csv(osp.join(".", "Results", "second_model_perf.csv")).sort_values(by='AUC', ascending=False)
first_model_auc = round_number(first_model_perf['AUC'].values[0])
second_model_auc = round_number(second_model_perf['AUC'].values[0])
only_pair_auc = round_number(second_model_keep_dim.loc[second_model_keep_dim['Dimension']=="Pairs", 'AUC'].values[0])
without_pair_auc = round_number(second_model_discard_dim.loc[second_model_discard_dim['Dimension']=="Pairs", 'AUC'].values[0])

# %%
for idx, row in first_model_keep_dim.iterrows():
    auc_m2_keep = round_number(second_model_keep_dim.loc[second_model_keep_dim['Dimension']==row['Dimension'], "AUC"].values[0])
    auc_m1_discard = round_number(first_model_discard_dim.loc[first_model_discard_dim['Dimension']==row['Dimension'], "AUC"].values[0])
    auc_m2_discard = round_number(second_model_discard_dim.loc[second_model_discard_dim['Dimension']==row['Dimension'], "AUC"].values[0])
    print("\\multirow{2}{*}{\\textbf{"+row['Dimension']+"}} & Only & "+str(round_number(row['AUC']))+"\\% & "+str(auc_m2_keep)+"\\% \\" + "\\")
    print("& Without & "+str(auc_m1_discard)+"\% &"+ str(auc_m2_discard)+"\%\\"+ "\\")
    print("\\noalign{\smallskip}")
    print("\hhline{~----}")
    print("\\noalign{\smallskip}")
print("\\multirow{2}{*}{\\textbf{Pair}} & Only & N/A &"+ str(only_pair_auc)+"\\%\\\\")
print("\\noalign{\smallskip}")
print("& Without & N/A & "+str(without_pair_auc)+"\\%\\\\")
print("\\noalign{\smallskip}")
print("\\hline")
print("\\noalign{\smallskip}")
print("\\textbf{All} & All & "+str(first_model_auc)+"\\% & "+str(second_model_auc)+"\\%\\\\")
print("\\noalign{\smallskip}")
# Out:
# \multirow{2}{*}{\textbf{Change}} & Only & 56.32\% & 62.58\% \\
# & Without & 81.94\% &83.1\%\\
# \noalign{\smallskip}
# \hhline{~----}
# \noalign{\smallskip}
# \multirow{2}{*}{\textbf{Text}} & Only & 57.27\% & 58.7\% \\
# & Without & 81.14\% &82.53\%\\
# \noalign{\smallskip}
# \hhline{~----}
# \noalign{\smallskip}
# \multirow{2}{*}{\textbf{Developer}} & Only & 79.5\% & 79.8\% \\
# & Without & 64.61\% &80.9\%\\
# \noalign{\smallskip}
# \hhline{~----}
# \noalign{\smallskip}
# \multirow{2}{*}{\textbf{Project}} & Only & 54.35\% & 61.68\% \\
# & Without & 81.75\% &83.64\%\\
# \noalign{\smallskip}
# \hhline{~----}
# \noalign{\smallskip}
# \multirow{2}{*}{\textbf{File}} & Only & 54.43\% & 52.6\% \\
# & Without & 82.17\% &83.1\%\\
# \noalign{\smallskip}
# \hhline{~----}
# \noalign{\smallskip}
# \multirow{2}{*}{\textbf{Pair}} & Only & N/A &76.4\%\\
# \noalign{\smallskip}
# & Without & N/A & 77.11\%\\
# \noalign{\smallskip}
# \hline
# \noalign{\smallskip}
# \textbf{All} & All & 82.86\% & 84.49\%\\
# \noalign{\smallskip}

# %% [markdown]
# ### Impact

# %%
df_feat_impact = df_feat_impact[df_feat_impact['impact'].notnull()]
df_feat_impact = df_feat_impact.reset_index(drop=True)
# df_feat_impact.to_csv(osp.join('.', 'Results', 'Impact', 'first_model_feat_impact.csv'), index=None)

# %%
df_feat_impact_2 = pd.read_csv(osp.join('.', 'Results', 'Impact', 'first_model_feat_impact.csv'))
# df_feat_impact = df_feat_impact[df_feat_impact['impact'].notnull()]
# attr = "insertions"
# test = df_feat_impact.loc[(df_feat_impact[attr].duplicated()==False)&(df_feat_impact['fold']!=0), [attr, "fold", "impact"]].sort_values("impact")
# test = test[test['impact'].notnull()==True].iloc[:-1, -1]
# test = f" & {round(test.min(), 2)} & {round(test.median(), 2)} & {round(test.max(), 2)}"
# test

# %%
# Creating a DataFrame from the new set of data
data = {
    'Feature': [
        'ratio_dep_chan_owner', 'project_changes_owner', 'pctg_cross_project_changes',
        'description_length', 'whole_within_project_changes', 'project_age',
        'projects_contributed_owner', 'pctg_cross_project_changes_owner', 'subject_length',
        'cross_project_changes_owner', 'num_file_changes', 'insertions',
        'last_mth_dep_proj_nbr', 'deletions', 'max_num_mod_file_dep_cha',
        'num_directory_files', 'cross_project_changes', 'whole_changes_owner',
        'num_file_types', 'has_feature_addition', 'is_corrective',
        'avg_num_dev_modified_files', 'is_refactoring', 'min_num_mod_file_dep_cha',
        'is_preventive', 'is_non_functional', 'num_dev_modified_files',
        'is_merge'
    ],
    'Ranking': [
        1, 2, 2, 3, 4, 5, 6, 6, 7, 7, 7, 8, 9, 9, 9, 10, 11, 11, 12, 13, 14, 14, 15, 16, 16, 17, 17, 18
    ]
}

# Creating the dataframe
df_most_impo_feat = pd.DataFrame(data)
classifiers = df_feat_impact['Classifier'].unique().tolist()
df_most_impo_feat['Classifier'] = [classifiers for _ in range(len(df_most_impo_feat))]
df_most_impo_feat = df_most_impo_feat.explode("Classifier")
df_most_impo_feat.reset_index(drop=True, inplace=True)

# %%
def map_impact_to_fold(row):
    # print(row)
    for i in range(10):
        row[f'fold{i}'] = df_feat_impact.loc[(df_feat_impact['Classifier']==row['Classifier'])&(df_feat_impact['fold']==i), [row['Feature'],  'fold', 'impact']].sort_values(by=row['Feature']).iloc[-1, -1]
    # print(row)
    return row

def retrieve_impact(row, func):
    df_sub = [row[f'fold{i}'] for i in range(10)]
    return func(df_sub)

# %%
df_most_impo_feat = df_most_impo_feat.apply(map_impact_to_fold, axis=1)
df_most_impo_feat['mean'] = df_most_impo_feat.apply(retrieve_impact, args=(np.mean,), axis=1) 
# df_most_impo_feat['median'] = df_most_impo_feat.apply(retrieve_impact, args=(np.median,), axis=1) 
# df_most_impo_feat['max'] = df_most_impo_feat.apply(retrieve_impact, args=(max,), axis=1) 
# df_most_impo_feat['max'] = df_most_impo_feat.apply(retrieve_impact, args=(max,), axis=1)

# %%
df_most_impo_feat.to_csv(osp.join('.', 'Results', 'first_feat_impact_import.csv'), index=None)

# %%
for idx, row in df_most_impo_feat[:10].iterrows():
    print(row["Feature"].replace("_", "\\_")+" & "+str(row['Ranking'])+" & "+str(round(row['min'], 2))+" & "+str(round(row['median'], 2))+" & "+str(round(row['max'], 2))+" \\\\")
